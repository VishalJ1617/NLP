# %% [markdown]
# Date : 15/12/2023

# %% [markdown]
# ## ANN for Sentiment Analysis

# %% [markdown]
# <img src="" alt="">

# %%
### --------------------
### Importing Librarires
### --------------------

import string
import re


from os import listdir


from nltk.corpus import stopwords
import nltk


from keras.preprocessing.text import Tokenizer
from keras.utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score



import numpy as np
# Out:
# 2023-12-16 09:17:39.392321: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-16 09:17:39.395317: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-16 09:17:39.433140: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-16 09:17:39.433170: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-16 09:17:39.433193: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-16 09:17:39.439800: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-16 09:17:39.440556: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-16 09:17:40.289352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/dai/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### Defining the function to read files one by one

# %%
# load doc into memory

def load_doc(filename):
    
    # open the file as read only
    file = open(filename, 'r')
    
    #read all text
    text = file.read()
    
    # close the file
    file.close()
    
    return text

# %%
# tetsting the 'load_doc' function

# reading a random file from the directory

text = load_doc('review_polarity/txt_sentoken/pos/cv026_29325.txt')

text
# Out:
# 'for those of us who weren\'t yet born when the 1960\'s rock \'n\' rolled around , monterey pop affords an affectionate glimpse of the music that influenced our parents to be hippies . \nfrom otis redding to jimi hendrix , janis joplin to the mamas and the papas , and jefferson airplane to the who , this documentary is jam-packed with contagious energy . \nbut i give fair warning that i will reveal the ending , which does not do the rest of the film the justice it deserves . \nshot in 1969 at an outdoor concert that precluded woodstock , the film defies the stereotype of the general population at the time . \nsure , some have painted their faces and smoke joints , but d . a . \npennebaker ( the war room , moon over broadway ) surprisingly chooses to show a broad spectrum of the audience . \nno matter who is watching , it all comes back to the talented musicians that stir your soul . \nthe excitement starts before the music even begins . \na young girl is cleaning thousands of seats and when asked why by an interviewer , she replies that she feels lucky to do so . \nthere are moments of organized craziness as john phillips , leader of the mamas and the papas and one of the concert organizers , tries to get in touch with dionne warwick . \nand when one band is tuning up , a member remarks , " finally , a decent sound system ! " \nyou can tell just by watching these first few moments that this show isn\'t about vanity , it\'s about playing the music you love to those who have an appreciation for it , a two-way street . \nthis interaction between audience and performer continues throughout the film and becomes infectious to the audience . \nit\'s impossible to tear your eyes away from janis joplin as she belts out her ballad about love being a ball and chain . \nand while the lyrics to " wild thing " may not be all that complicated , watching jimi hendrix mime having sex with his guitar is as captivating as otis redding singing about love . \neven if you don\'t recognize every band you see on stage , you can imagine being as enthralled by their work as the public sitting in those seats . \nthe only drawback to the film is the ending , which unfortunately i must reveal . \nall the other bands , big names then and still today , got approximately 7 to 10 minutes of screen time . \nin contrast , the last band on camera , a wholly forgettable one , gets an entire 18 minutes of screen time . \nfor a film that\'s only 78 minutes long , that\'s too large of a chunk , especially when previous acts are much more stimulating . \nall in all , monterey pop is a precious , rare look at a time period that still holds sway over us . \nthe variety of music , as well as the beautifully shot performances , are easy to become immersed in . \nif there was ever any question as to why most of these bands were so popular , this is quickly dispelled . \nit\'s almost depressing to think that music this moving doesn\'t get made much anymore . \ninstead we\'re stuck with * nsync , the backstreet boys , and jennifer lopez , all of whom should have stuck with modeling . \n'

# %%
#Turn a doc into clean token
def clean_doc(doc):
    #Split ino tokens by white space
    tokens=doc.split()
    #Prepare regax for char filtering
    re_punc=re.compile('[%s]' % re.escape(string.punctuation))
    #remove punctuation from each words
    tokens=[re_punc.sub('',w)for w in tokens]
    #remove remaining tokens that are not alphabetic
    tokens=[word for word in tokens if word.isalpha()]
    #filter out stop words
    stop_words=set(stopwords.words('english'))
    tokens=[w for w in tokens if not w in stop_words]
    #Filter out short tokens
    tokens=[word for word in tokens if len(word)>1]
    return tokens

# %%
clean=clean_doc(text)
len(clean)
# Out:
# 261

# %%
# load doc, clean and return line of tokens
def doc_to_line(filename,vocab):
    #load the doc
    doc=load_doc(filename)
    #clean doc
    tokens=clean_doc(doc)
    #Filter the vocab
    tokens=[w for w in tokens if w in vocab]
    return ' '.join(tokens)

# %%
vocab=open('vocab.txt')
vocab=vocab.read().split()

# %%
doc_to_line('review_polarity/txt_sentoken/pos/cv026_29325.txt',vocab)
# Out:
# 'us werent yet born rock rolled around monterey pop affectionate glimpse music influenced parents hippies otis redding jimi hendrix janis joplin mamas papas jefferson airplane documentary jampacked contagious energy give fair warning reveal ending rest film justice deserves shot outdoor concert film defies stereotype general population time sure painted faces smoke joints war room moon broadway surprisingly chooses show broad spectrum audience matter watching comes back talented musicians stir soul excitement starts music even begins young girl cleaning thousands seats asked interviewer replies feels lucky moments organized craziness john phillips leader mamas papas one concert tries get touch one band tuning member remarks finally decent sound system tell watching first moments show isnt vanity playing music love appreciation street interaction audience performer continues throughout film becomes infectious audience impossible tear eyes away janis joplin belts ballad love ball chain lyrics wild thing may complicated watching jimi hendrix mime sex guitar captivating otis redding singing love even dont recognize every band see stage imagine enthralled work public sitting seats drawback film ending unfortunately must reveal bands big names still today got approximately minutes screen time contrast last band camera wholly forgettable one gets entire minutes screen time film thats minutes long thats large chunk especially previous acts much stimulating monterey pop precious rare look time period still holds sway us variety music well beautifully shot performances easy become immersed ever question bands popular quickly almost depressing think music moving doesnt get made much anymore instead stuck backstreet boys jennifer lopez stuck modeling'

# %% [markdown]
# ### Function to read all the docs

# %%
def process_docs(directory,vocab,is_train):
    documents = list()
    #walks through all the files in the folder
    for filename in listdir(directory):
        #skip any reviews in test set
        if is_train and filename.startswith('cv9'):
            continue
        if not is_train and not filename.startswith('cv9'):
            continue
        #create a full path of the file to open
        path = directory + '/'+filename
        #load the doc
        doc = load_doc(path)
        #clean the data
        tokens = clean_doc(doc)
        #load the data
        documents.append(tokens)
    return documents

# %%
lines = process_docs('review_polarity/review_polarity/txt_sentoken/pos', vocab, False)

len(lines)
# Out:
# 100

# %%
# load and clean a dataset


def load_clean_dataset(vocab, is_train):
    
    # load documents
    neg = process_docs('review_polarity/review_polarity/txt_sentoken/neg',
                      vocab, is_train)
    
    pos = process_docs('review_polarity/review_polarity/txt_sentoken/pos',
                      vocab, is_train)
    
    docs = neg + pos
    
    # prepare labels
    
    labels = [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
    
    return docs, labels

# %%
train, train_labels = load_clean_dataset(vocab, True)
test, test_labels = load_clean_dataset(vocab, False)

# %%
len(train), len(train_labels)
# Out:
# (1800, 1800)

# %%
len(test), len(test_labels)
# Out:
# (200, 200)

# %% [markdown]
# ## Build ANN model

# %%
# define the model



def define_model(n_words):
    
    
    
    # define network
    
    model = Sequential()
    
    model.add(Dense(50,
                   input_shape = (n_words,),
                   activation = 'relu'
                   )
             )
    
    model.add(Dense(1,
                   activation = 'sigmoid'
                   )
             )
    
    
    
    # compile network
    
    model.compile(loss = 'binary_crossentropy',
                 optimizer = 'adam',
                 metrics = ['accuracy']
                 )
    
    
    
    # summarize the defined model
    
    model.summary()
    
    
    
    
    # Plotting the model
    
    plot_model(model, 
              to_file = 'model.png',
              show_shapes = True
              )

    
    
    return model

# %%
# model call

define_model(100)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                5050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 5101 (19.93 KB)
# Trainable params: 5101 (19.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit a tokenizer

def create_tokenizer(lines):
    
    tokenizer = Tokenizer()
    
    tokenizer.fit_on_texts(lines)
    
    return tokenizer



# Create the tokenizer

tokenizer = create_tokenizer(train)

# %%
# encode data

x_train = tokenizer.texts_to_matrix(train,
                                   mode = 'binary')

x_train.shape
# Out:
# (1800, 44277)

# %%
x_test = tokenizer.texts_to_matrix(test,
                                   mode = 'binary')

x_test.shape
# Out:
# (200, 44277)

# %%
tokenizer.word_docs
# Out:
# defaultdict(int,
#             {'ensemble': 45,
#              'angst': 12,
#              'thing': 524,
#              'cooks': 1,
#              'good': 1033,
#              'shes': 243,
#              'textbook': 9,
#              'product': 79,
#              'doesnt': 734,
#              'comes': 520,
#              'game': 180,
#              'plan': 120,
#              'flair': 29,
#              'stopping': 11,
#              'keep': 280,
#              'faculty': 6,
#              'storm': 37,
#              'know': 674,
#              'prinze': 18,
#              'remaining': 49,
#              'grown': 39,
#              'make': 899,
#              'shawn': 9,
#              'rabid': 10,
#              'ashton': 4,
#              'program': 40,
#              'whiff': 4,
#              'long': 530,
#              'intentions': 34,
#              'work': 640,
#              'absurd': 47,
#              'sticks': 28,
#              'kind': 366,
#              'blair': 39,
#              'order': 215,
#              'humor': 261,
#              'unlikely': 49,
#              'newly': 24,
#              'entirely': 102,
#              'boring': 201,
#              'draw': 59,
#              'realized': 69,
#              'rounding': 12,
#              'meets': 164,
#              'nostalgia': 23,
#              'part': 473,
#              'needy': 4,
#              'depth': 112,
#              'year': 386,
#              'result': 187,
#              'film': 1553,
#              'mildly': 34,
#              'films': 941,
#              'called': 265,
#              'life': 707,
#              'mentioned': 69,
#              'decent': 129,
#              'bland': 75,
#              'hit': 204,
#              'craze': 6,
#              'taking': 183,
#              'toward': 77,
#              'swat': 5,
#              'charisma': 40,
#              'studdly': 1,
#              'extraordinarily': 15,
#              'whole': 353,
#              'find': 510,
#              'concept': 83,
#              'audience': 554,
#              'far': 422,
#              'assembled': 23,
#              'attractive': 61,
#              'often': 258,
#              'giggly': 1,
#              'arrival': 30,
#              'assistance': 20,
#              'maybe': 243,
#              'worst': 215,
#              'cruel': 34,
#              'epitome': 13,
#              'henry': 48,
#              'along': 398,
#              'end': 661,
#              'zak': 2,
#              'team': 171,
#              'artist': 63,
#              'boymeetsgirl': 3,
#              'popular': 145,
#              'porn': 30,
#              'houses': 20,
#              'handling': 23,
#              'ordeal': 10,
#              'old': 471,
#              'fullyarmed': 1,
#              'appeal': 74,
#              'story': 948,
#              'featured': 39,
#              'desired': 19,
#              'leave': 183,
#              'laughing': 92,
#              'monk': 5,
#              'meal': 9,
#              'including': 256,
#              'julia': 46,
#              'standard': 91,
#              'intelligent': 137,
#              'others': 237,
#              'everything': 351,
#              'warmth': 17,
#              'happen': 170,
#              'unmistakable': 5,
#              'role': 551,
#              'hate': 93,
#              'previously': 58,
#              'sophomore': 7,
#              'strictly': 32,
#              'well': 895,
#              'attached': 24,
#              'segment': 30,
#              'however': 579,
#              'drive': 71,
#              'obviously': 187,
#              'pitted': 4,
#              'crazy': 63,
#              'orth': 2,
#              'hatosy': 4,
#              'course': 439,
#              'impressive': 161,
#              'last': 527,
#              'things': 528,
#              'paper': 33,
#              'run': 208,
#              'frequently': 60,
#              'activities': 20,
#              'college': 88,
#              'screen': 455,
#              'circumstances': 45,
#              'chef': 13,
#              'adorable': 18,
#              'youve': 141,
#              'imogen': 1,
#              'got': 322,
#              'main': 300,
#              'formula': 74,
#              'latest': 150,
#              'star': 355,
#              'couple': 275,
#              'selma': 3,
#              'ordinary': 37,
#              'unattractive': 5,
#              'dialogue': 349,
#              'sort': 214,
#              'impatiently': 2,
#              'banal': 19,
#              'dad': 60,
#              'movies': 726,
#              'crowd': 60,
#              'like': 1322,
#              'aspiring': 17,
#              'clich': 56,
#              'teen': 79,
#              'teenage': 75,
#              'genre': 181,
#              'possibly': 104,
#              'talent': 174,
#              'breakout': 6,
#              'together': 386,
#              'young': 441,
#              'hot': 92,
#              'perhaps': 335,
#              'actually': 528,
#              'finished': 32,
#              'winkler': 6,
#              'show': 412,
#              'nicest': 3,
#              'fortunately': 41,
#              'fantasy': 68,
#              'romance': 121,
#              'reel': 23,
#              'folks': 66,
#              'al': 38,
#              'highlight': 37,
#              'identity': 64,
#              'luck': 53,
#              'capitalize': 14,
#              'guy': 359,
#              'welcome': 66,
#              'always': 386,
#              'fluff': 21,
#              'antics': 36,
#              'sequence': 243,
#              'scenario': 29,
#              'refreshing': 41,
#              'fashion': 80,
#              'suit': 55,
#              'tasteless': 17,
#              'around': 601,
#              'say': 522,
#              'son': 199,
#              'boylosesgirl': 1,
#              'certain': 157,
#              'one': 1558,
#              'waited': 16,
#              'freddie': 19,
#              'jr': 57,
#              'seemed': 160,
#              'imitators': 1,
#              'boydrinksentirebottleofshampooandmayormaynotgetgirlback': 1,
#              'walking': 70,
#              'could': 781,
#              'amused': 10,
#              'girls': 103,
#              'ahh': 3,
#              'father': 272,
#              'families': 32,
#              'stiles': 7,
#              'support': 66,
#              'restless': 17,
#              'goofyembarrassing': 1,
#              'comedy': 447,
#              'tvs': 40,
#              'despite': 252,
#              'gears': 8,
#              'clever': 137,
#              'accustomed': 8,
#              'takeoff': 7,
#              'even': 1156,
#              'feature': 159,
#              'yes': 196,
#              'dull': 106,
#              'host': 29,
#              'cops': 67,
#              'freshman': 6,
#              'centered': 10,
#              'plot': 770,
#              'cast': 480,
#              'miramax': 12,
#              'characters': 900,
#              'bound': 43,
#              'als': 5,
#              'movie': 1372,
#              'gets': 587,
#              'shows': 315,
#              'kutcher': 1,
#              'cooking': 14,
#              'ray': 45,
#              'funny': 444,
#              'sources': 13,
#              'uninspired': 29,
#              'would': 997,
#              'requirements': 9,
#              'commodity': 13,
#              'way': 913,
#              'conveniently': 15,
#              'cuteness': 9,
#              'followed': 61,
#              'looked': 91,
#              'fonz': 2,
#              'obvious': 223,
#              'convincing': 106,
#              'flashcards': 1,
#              'girl': 260,
#              'jokes': 155,
#              'trying': 395,
#              'drawn': 62,
#              'something': 645,
#              'catalogue': 2,
#              'resulting': 27,
#              'cook': 19,
#              'project': 133,
#              'radiate': 4,
#              'occasional': 55,
#              'stealing': 31,
#              'read': 144,
#              'unknown': 42,
#              'previous': 140,
#              'really': 778,
#              'belittling': 1,
#              'straightlaced': 7,
#              'bad': 681,
#              'sure': 361,
#              'nothing': 520,
#              'yet': 422,
#              'bathroom': 36,
#              'puts': 109,
#              'seemingly': 101,
#              'besides': 51,
#              'contrived': 66,
#              'version': 184,
#              'anyone': 325,
#              'night': 280,
#              'falling': 64,
#              'closing': 37,
#              'martin': 93,
#              'offensive': 52,
#              'think': 537,
#              'scene': 708,
#              'swiped': 1,
#              'mirror': 26,
#              'call': 167,
#              'directly': 66,
#              'riot': 19,
#              'showing': 113,
#              'car': 202,
#              'billy': 75,
#              'accusing': 3,
#              'reconsider': 2,
#              'released': 151,
#              'every': 608,
#              'player': 59,
#              'smith': 79,
#              'restaurant': 34,
#              'woos': 12,
#              'elegant': 14,
#              'sake': 39,
#              'goes': 473,
#              'thugs': 20,
#              'tommy': 41,
#              'hours': 185,
#              'starts': 238,
#              'three': 383,
#              'africanamericans': 4,
#              'chuckle': 21,
#              'ever': 498,
#              'violently': 5,
#              'somewhere': 106,
#              'mayhem': 22,
#              'doors': 32,
#              'instead': 416,
#              'black': 257,
#              'cameo': 83,
#              'date': 89,
#              'case': 283,
#              'get': 974,
#              'girlfriends': 19,
#              'another': 704,
#              'point': 436,
#              'bananas': 7,
#              'entire': 300,
#              'booty': 3,
#              'allens': 15,
#              'include': 95,
#              'isnt': 553,
#              'youd': 85,
#              'reason': 319,
#              'woody': 61,
#              'subway': 12,
#              'tim': 88,
#              'screenplay': 207,
#              'destroying': 25,
#              'made': 647,
#              'normal': 83,
#              'buffoons': 7,
#              'awful': 106,
#              'joke': 100,
#              'provided': 68,
#              'chuckles': 18,
#              'ripoff': 31,
#              'follows': 141,
#              'importantly': 43,
#              'open': 117,
#              'careers': 24,
#              'running': 243,
#              'sexual': 132,
#              'plays': 525,
#              'everyone': 327,
#              'wouldnt': 157,
#              'woman': 320,
#              'williams': 103,
#              'dee': 4,
#              'wont': 211,
#              'blind': 35,
#              'ok': 69,
#              'woo': 35,
#              'infuriating': 7,
#              'involved': 192,
#              'def': 2,
#              'davidson': 9,
#              'pinkett': 5,
#              'taunt': 4,
#              'embarassing': 6,
#              'stolen': 47,
#              'causing': 27,
#              'house': 220,
#              'months': 80,
#              'else': 285,
#              'wild': 107,
#              'questioning': 16,
#              'person': 232,
#              'tolerate': 8,
#              'thinks': 115,
#              'scorseses': 12,
#              'jams': 3,
#              'back': 638,
#              'either': 294,
#              'jada': 5,
#              'various': 126,
#              'best': 756,
#              'watching': 369,
#              'killed': 161,
#              'writer': 141,
#              'miss': 90,
#              'cant': 439,
#              'seminude': 1,
#              'cake': 15,
#              'theater': 162,
#              'literally': 84,
#              'going': 561,
#              'bosom': 3,
#              'parents': 135,
#              'minutes': 426,
#              'phone': 66,
#              'refuse': 12,
#              'charm': 99,
#              'trunk': 15,
#              'fact': 524,
#              'position': 58,
#              'look': 542,
#              'many': 704,
#              'let': 228,
#              'mere': 39,
#              'julie': 41,
#              'time': 1099,
#              'halls': 11,
#              'grier': 14,
#              'ronald': 7,
#              'introduces': 40,
#              'wrong': 272,
#              'lizs': 3,
#              'stein': 4,
#              'golf': 3,
#              'referred': 20,
#              'hold': 110,
#              'female': 109,
#              'toss': 9,
#              'emotion': 66,
#              'especially': 340,
#              'says': 190,
#              'sounds': 107,
#              'constant': 66,
#              'powder': 9,
#              'happened': 136,
#              'granted': 46,
#              'brains': 28,
#              'add': 150,
#              'ball': 44,
#              'brothel': 3,
#              'liz': 9,
#              'see': 872,
#              'much': 1008,
#              'discovers': 89,
#              'seen': 563,
#              'mayo': 3,
#              'vera': 7,
#              'blue': 76,
#              'violence': 195,
#              'proving': 22,
#              'parade': 21,
#              'advise': 3,
#              'nerdy': 6,
#              'rebecca': 24,
#              'later': 300,
#              'shayne': 2,
#              'jawbreaker': 5,
#              'conviction': 22,
#              'darren': 8,
#              'reflex': 2,
#              'stomach': 22,
#              'princess': 40,
#              'given': 365,
#              'clan': 10,
#              'eventually': 180,
#              'stares': 9,
#              'shed': 20,
#              'without': 488,
#              'played': 495,
#              'four': 189,
#              'rose': 39,
#              'mcgowan': 12,
#              'number': 167,
#              'nosed': 1,
#              'reagan': 9,
#              'benz': 3,
#              'parenting': 4,
#              'start': 241,
#              'fern': 3,
#              'cheeks': 6,
#              'royalty': 6,
#              'dialog': 38,
#              'trite': 37,
#              'ask': 115,
#              'di': 8,
#              'go': 650,
#              'better': 602,
#              'victim': 79,
#              'stuckup': 4,
#              'public': 77,
#              'director': 714,
#              'roldan': 3,
#              'interrogates': 2,
#              'brag': 5,
#              'gore': 70,
#              'profanity': 32,
#              'stick': 56,
#              'pam': 20,
#              'people': 756,
#              'overdress': 1,
#              'scenes': 694,
#              'put': 324,
#              'presence': 146,
#              'teacher': 65,
#              'considerably': 24,
#              'ritual': 11,
#              'intelligence': 93,
#              'steins': 2,
#              'wannabes': 11,
#              'fare': 71,
#              'likely': 133,
#              'spice': 27,
#              'rest': 330,
#              'action': 490,
#              'cruz': 8,
#              'tape': 35,
#              'high': 311,
#              'lines': 238,
#              'learning': 34,
#              'runs': 166,
#              'grab': 18,
#              'advised': 12,
#              'taste': 50,
#              'teachers': 8,
#              'institution': 17,
#              'wit': 64,
#              'walk': 84,
#              'fab': 2,
#              'detective': 83,
#              'prank': 7,
#              'check': 65,
#              'turn': 261,
#              'id': 136,
#              'reference': 35,
#              'stripped': 14,
#              'question': 218,
#              'disgusting': 17,
#              'heathers': 9,
#              'school': 201,
#              'gayheart': 10,
#              'brutal': 40,
#              'body': 193,
#              'investigates': 3,
#              'fast': 110,
#              'daily': 21,
#              'sometimes': 188,
#              'setup': 70,
#              'larger': 34,
#              'viewer': 139,
#              'dead': 249,
#              'compacts': 1,
#              'avoid': 80,
#              'skills': 56,
#              'sex': 227,
#              'rated': 99,
#              'ridiculous': 112,
#              'cover': 76,
#              'mouth': 77,
#              'rape': 32,
#              'murder': 160,
#              'guarantee': 16,
#              'ugly': 59,
#              'eating': 35,
#              'taken': 179,
#              'anyway': 153,
#              'actresses': 36,
#              'mature': 37,
#              'posh': 7,
#              'dont': 707,
#              'pornographic': 9,
#              'offer': 92,
#              'feeling': 166,
#              'older': 79,
#              'makeup': 51,
#              'please': 83,
#              'hard': 351,
#              'charlotte': 9,
#              'realistic': 94,
#              'bruised': 4,
#              'lipstick': 7,
#              'shut': 35,
#              'forget': 102,
#              'teenagers': 58,
#              'name': 282,
#              'oprah': 5,
#              'idiots': 16,
#              'highway': 18,
#              'nightmarish': 10,
#              'rise': 53,
#              'convince': 40,
#              'skeleton': 4,
#              'accompanying': 12,
#              'local': 159,
#              'returned': 33,
#              'boat': 50,
#              'lurk': 3,
#              'suddenly': 115,
#              'filled': 131,
#              'quite': 420,
#              'meanwhile': 110,
#              'love': 567,
#              'lets': 162,
#              'thoroughly': 62,
#              'next': 328,
#              'rubber': 16,
#              'uninteresting': 41,
#              'boyfriend': 57,
#              'didnt': 384,
#              'nights': 52,
#              'phifer': 6,
#              'wished': 16,
#              'filleted': 1,
#              'accidentally': 52,
#              'relaxation': 5,
#              'slayings': 2,
#              'want': 396,
#              'hotel': 59,
#              'raved': 2,
#              'club': 71,
#              'driving': 55,
#              'presumably': 28,
#              'wielding': 11,
#              'elated': 1,
#              'kill': 199,
#              'desparate': 1,
#              'jennifer': 68,
#              'knockknock': 1,
#              'overbearing': 25,
#              'misdeed': 2,
#              'trip': 91,
#              'chalk': 3,
#              'heard': 130,
#              'dump': 11,
#              'possible': 199,
#              'rejects': 9,
#              'tries': 280,
#              'storms': 10,
#              'guessed': 24,
#              'survive': 61,
#              'island': 70,
#              'strange': 140,
#              'example': 237,
#              'door': 84,
#              'secluded': 6,
#              'creates': 82,
#              'died': 65,
#              'breakdown': 22,
#              'two': 929,
#              'heres': 61,
#              'circles': 20,
#              'contest': 17,
#              'incessantly': 16,
#              'scroll': 2,
#              'unless': 73,
#              'memories': 50,
#              'friends': 266,
#              'karla': 7,
#              'used': 271,
#              'tyrell': 4,
#              'soon': 292,
#              'roommate': 20,
#              'conjures': 7,
#              'libido': 2,
#              'verge': 11,
#              'hooked': 11,
#              'cleaning': 16,
#              'strobe': 5,
#              'resort': 17,
#              'dark': 196,
#              'hunt': 40,
#              'mountain': 33,
#              'lightning': 13,
#              'sees': 111,
#              'chortling': 2,
#              'learn': 142,
#              'responsible': 60,
#              'quirky': 42,
#              'satisfied': 19,
#              'give': 408,
#              'slash': 2,
#              'man': 680,
#              'hunted': 8,
#              'staff': 22,
#              'power': 153,
#              'never': 753,
#              'count': 70,
#              'figure': 150,
#              'intense': 68,
#              'singing': 50,
#              'blinking': 3,
#              'touch': 91,
#              'ranted': 1,
#              'boils': 15,
#              'everywhere': 40,
#              'nervous': 33,
#              'season': 54,
#              'looks': 325,
#              'wearing': 47,
#              'wry': 11,
#              'leads': 185,
#              'lights': 37,
#              'summer': 173,
#              'screaming': 44,
#              'still': 626,
#              'seems': 619,
#              'karaoke': 5,
#              'frightened': 26,
#              'tropical': 7,
#              'potential': 138,
#              'chased': 25,
#              'ocean': 40,
#              'beau': 8,
#              'sequal': 1,
#              'kids': 202,
#              'mehki': 1,
#              'secretly': 33,
#              'dance': 66,
#              'survived': 16,
#              'vacation': 30,
#              'schoolwork': 2,
#              'besieged': 4,
#              'mindless': 25,
#              'irritated': 4,
#              'word': 175,
#              'appropriate': 84,
#              'suspense': 132,
#              'lady': 64,
#              'bar': 52,
#              'outages': 1,
#              'begin': 157,
#              'housekeeping': 2,
#              'paranoia': 15,
#              'deaths': 24,
#              'means': 146,
#              'hand': 248,
#              'words': 166,
#              'slicker': 6,
#              'needing': 7,
#              'hook': 32,
#              'brandy': 9,
#              'giggling': 3,
#              'sleep': 50,
#              'hewitt': 11,
#              'practically': 45,
#              'karlas': 4,
#              'slashfest': 1,
#              'grade': 27,
#              'deserted': 20,
#              'killer': 134,
#              'eerie': 30,
#              'mysteriously': 13,
#              'anniversary': 16,
#              'first': 918,
#              'venue': 3,
#              'diminuitive': 1,
#              'opens': 146,
#              'shadows': 22,
#              'concentrate': 11,
#              'campiness': 7,
#              'might': 443,
#              'true': 282,
#              'dismal': 20,
#              'visions': 21,
#              'james': 275,
#              'amount': 107,
#              'arrive': 35,
#              'consecutive': 6,
#              'manage': 71,
#              'army': 68,
#              'magnificent': 32,
#              'finds': 254,
#              'seem': 400,
#              'loss': 43,
#              'mctiernans': 4,
#              'act': 207,
#              'faceless': 7,
#              'thoughtprovoking': 27,
#              'lot': 456,
#              'kings': 24,
#              'requesting': 3,
#              'notice': 69,
#              'dances': 14,
#              'warriors': 17,
#              'needs': 178,
#              'kulich': 1,
#              'ambassador': 13,
#              'arab': 9,
#              'viking': 4,
#              'bit': 372,
#              'conversations': 31,
#              'farfetched': 12,
#              'bottom': 64,
#              'goals': 16,
#              'twelve': 22,
#              'hereafter': 11,
#              'assortment': 16,
#              'wants': 345,
#              'translator': 5,
#              'youll': 163,
#              'jungle': 29,
#              'vs': 36,
#              'fell': 34,
#              'murky': 13,
#              'warrior': 25,
#              'efforts': 55,
#              'herger': 1,
#              'sharif': 2,
#              'swallow': 20,
#              'idea': 271,
#              'whose': 321,
#              'insert': 12,
#              'must': 440,
#              'listening': 33,
#              'dennis': 68,
#              'bigname': 6,
#              'becomes': 376,
#              'duel': 5,
#              'fights': 47,
#              'braveheart': 24,
#              'poet': 7,
#              'pointless': 77,
#              'summons': 2,
#              'thus': 100,
#              'suspect': 64,
#              'chittering': 1,
#              'bailed': 3,
#              'thrillers': 48,
#              'thirteen': 9,
#              'baghdad': 1,
#              'northmen': 1,
#              'storh': 1,
#              'interesting': 425,
#              'zorro': 5,
#              'turned': 156,
#              'amidst': 20,
#              'king': 113,
#              'vikings': 4,
#              'stars': 300,
#              'sciencefiction': 15,
#              'facing': 19,
#              'mourning': 4,
#              'flick': 139,
#              'fun': 377,
#              'small': 294,
#              'outsider': 17,
#              'goofy': 56,
#              'westworld': 1,
#              'messenger': 10,
#              'kingdom': 13,
#              'character': 914,
#              'theres': 563,
#              'whos': 201,
#              'theyre': 266,
#              'examination': 17,
#              'forms': 31,
#              'channel': 18,
#              'predator': 10,
#              'discover': 92,
#              'michael': 238,
#              'villains': 52,
#              'battle': 137,
#              'language': 93,
#              'development': 96,
#              'threatening': 45,
#              'attack': 70,
#              'script': 488,
#              'lack': 188,
#              'medieval': 11,
#              'kicked': 19,
#              'echo': 9,
#              'villain': 120,
#              'tagteam': 3,
#              'runaway': 14,
#              'direction': 238,
#              'vladimir': 4,
#              'target': 70,
#              'suffers': 48,
#              'die': 145,
#              'antonio': 22,
#              'evil': 229,
#              'started': 72,
#              'omar': 12,
#              'grunting': 5,
#              'leader': 84,
#              'john': 423,
#              'took': 131,
#              'basis': 49,
#              'legend': 62,
#              'importance': 29,
#              'similarities': 19,
#              'mask': 29,
#              'personality': 89,
#              'cultures': 9,
#              'looker': 2,
#              'vision': 56,
#              'eaters': 5,
#              'particularly': 204,
#              'group': 238,
#              'supernatural': 32,
#              'cannibals': 1,
#              'mob': 40,
#              'fireside': 1,
#              'attracted': 30,
#              'mctiernan': 6,
#              'line': 298,
#              'banderas': 19,
#              'seven': 78,
#              'soothsayer': 1,
#              'roles': 218,
#              'epic': 62,
#              'meeting': 58,
#              'beautifullyrendered': 1,
#              'friendships': 7,
#              'live': 234,
#              'north': 36,
#              'answer': 87,
#              'cracks': 13,
#              'blackface': 1,
#              'caves': 4,
#              'satisfying': 56,
#              'aggression': 7,
#              'ahmed': 6,
#              'shame': 87,
#              'sword': 25,
#              'anything': 455,
#              'manages': 204,
#              'ibn': 4,
#              'buliwyf': 1,
#              'coma': 10,
#              'heads': 83,
#              'hands': 123,
#              'competing': 4,
#              'rent': 67,
#              'arrives': 59,
#              'joyous': 4,
#              'particular': 122,
#              'fahdlan': 4,
#              'also': 961,
#              'crichton': 7,
#              'directed': 256,
#              'novel': 156,
#              'swing': 10,
#              'wolves': 10,
#              'danzas': 1,
#              'popping': 16,
#              'unsuspecting': 13,
#              'double': 49,
#              'linear': 8,
#              'stairs': 7,
#              'levity': 7,
#              'least': 484,
#              'works': 280,
#              'appears': 190,
#              'goodguy': 2,
#              'madsen': 10,
#              'persona': 38,
#              'complete': 158,
#              'set': 397,
#              'illegal': 23,
#              'womans': 23,
#              'within': 160,
#              'praised': 12,
#              'consciousness': 8,
#              'mahem': 1,
#              'collegue': 1,
#              'relationship': 247,
#              'save': 203,
#              'guns': 57,
#              'covered': 45,
#              'said': 261,
#              'deserved': 34,
#              'tony': 57,
#              'confusion': 33,
#              'money': 317,
#              'looking': 301,
#              'respects': 18,
#              'care': 234,
#              'outset': 19,
#              'familiar': 148,
#              'death': 273,
#              'establish': 15,
#              'right': 525,
#              'exactly': 238,
#              'majority': 33,
#              'passes': 38,
#              'sound': 179,
#              'less': 313,
#              'skin': 38,
#              'confusing': 72,
#              'explanation': 51,
#              'ingrained': 4,
#              'filmmakers': 155,
#              ...})

# %%
#define network

n_words=x_train.shape[1]

model=define_model(n_words)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 50)                2213900
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2213951 (8.45 MB)
# Trainable params: 2213951 (8.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,np.array(train_labels),batch_size=10,epochs=10)
# Out:
# Epoch 1/10
# 180/180 [==============================] - 3s 14ms/step - loss: 0.4242 - accuracy: 0.8006
# Epoch 2/10
# 180/180 [==============================] - 2s 14ms/step - loss: 0.0252 - accuracy: 0.9961
# Epoch 3/10
# 180/180 [==============================] - 2s 14ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 4/10
# 180/180 [==============================] - 2s 14ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 5/10
# 180/180 [==============================] - 2s 14ms/step - loss: 6.8210e-04 - accuracy: 1.0000
# Epoch 6/10
# 180/180 [==============================] - 2s 14ms/step - loss: 3.8418e-04 - accuracy: 1.0000
# Epoch 7/10
# 180/180 [==============================] - 2s 14ms/step - loss: 2.4414e-04 - accuracy: 1.0000
# Epoch 8/10
# 180/180 [==============================] - 2s 14ms/step - loss: 1.6984e-04 - accuracy: 1.0000
# Epoch 9/10
# 180/180 [==============================] - 2s 14ms/step - loss: 1.2468e-04 - accuracy: 1.0000
# Epoch 10/10
# 180/180 [==============================] - 2s 14ms/step - loss: 9.4954e-05 - accuracy: 1.0000

# %%
# Plotting the architecture of the model

plot_model(model, 
           show_dtype = True,
          show_layer_activations = True,
          show_shapes = True,
          show_layer_names = True)

# %%
model.evaluate(x_test, np.array(test_labels), batch_size = 1)
# Out:
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2467 - accuracy: 0.9150
# [0.24665646255016327, 0.9150000214576721]

# %%
text11 = 'Best movie ever! It was great, I will definitely recommend it.'
text22 = 'This is a bad movie'

# %% [markdown]
# def predict_sentiment(review):
#
#     #clean
#     token = clean_doc(review)
#
#     #convert to line
#     line = ' '.join(token)
#
#     #encode
#     encoded = tokenizer.texts_to_matrix((line), mode = 'binary')
#
#     #predict sentiment
#     yhat = model.predict(encoded, verbose = 0)
#
#     # retrieve predicted percentage and label
#     percent_pos = yhat[0,0]
#
#     if round(percent_pos) == 0:
#
#         return (1 - percent_pos), 'NEGATIVE'
#
#     return percent_pos, 'POSITIVE'

# %%
def predict_data(text,vocab):
    
    tokens = clean_doc(text)
    tokens = [w for w in tokens if w in vocab]
    tokens = ' '.join(tokens)
    x_new = tokenizer.texts_to_matrix([tokens],mode = 'binary')
    y_pred = model.predict(x_new,verbose=0)
    if round(y_pred[0][0])==1:
        print("Positive Review: ", y_pred[0][0])
    elif(round(y_pred[0][0])==0):
        print("Negative Review: ", y_pred[0][0])

# %%
predict_data(text22,vocab)
print(percentage,sentiment)
# Out:
# Negative Review:  0.33531168
# 0.5695055425167084 NEGATIVE

# %%
predict_data(text11, vocab)
# Out:
# Positive Review:  0.6055102
