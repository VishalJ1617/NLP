# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 23c:
#
# ## MNIST feminist Data
#
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
# Lets import some libraries
import os

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from datetime import datetime, timedelta

from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow as tf

# %matplotlib inline

# %%
physical_devices = tf.config.list_physical_devices('GPU')

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Strictly for tensorflow version 2.12
### To hide bugs throwing warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Some basic parameters

inpDir = '/home/dai/6. DNN/CNN/Flower' # location where input data is stored
outDir = '../output' # location to store outputs
modelDir='../model'
subDir='flower_photos'
altName = 'Grp_2_project'



RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results

EPOCHS = 70  # number of cycles to run

ALPHA = 0.001  # learning rate

TEST_SIZE = 0.2 # What fraction we want to keep for testing

BATCH_SIZE = 32

FACTOR_LR = 0.5

LR_PATIENCE = 2

PATIENCE = 10
IMG_HEIGHT = 190
IMG_WIDTH = 190


# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (12,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }
CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
def fn_plot_label(tr_ds, ts_ds):


    plt.figure(figsize = (15,5))  # instantiate the figure

    # -----------------------------------------------------------------------------------------

    # labels for the training set

    plt.subplot(1,2,1) # first of the 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis = 0).numpy() # get the labels

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color = 'DarkBlue') # barplot the counts

    plt.xticks(range(len(unique)), class_names)

    plt.title('Training set')


    # -----------------------------------------------------------------------------------------

    # labels for the testing set

    plt.subplot(1,2,2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis = 0).numpy()

    unique_tst, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique_tst)), counts, align='center', color = 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Testing set')

# %% [markdown]
# ###  Using Flower dataset

# %% [markdown]
# ## Converting to Datsets  from a directory

# %%
import tensorflow as tf
import pathlib
dataset_url = "http://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,fname = 'flower_photos',untar = True)
data_dir = pathlib.Path(data_dir)

# %%
os.listdir(data_dir)
# Out:
# ['sunflowers', 'daisy', 'dandelion', 'roses', 'tulips', 'LICENSE.txt']

# %%
# Creating training data

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,  # path to the data directory
    validation_split=TEST_SIZE, # What is the ratio of validation data
    subset='training', #purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], # images of all the sizes will be squeezed to 150 x 150 image size
    batch_size= BATCH_SIZE
)

# test data

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,  # path to the data directory
    validation_split=TEST_SIZE, # What is the ratio of validation data
    subset='validation', #purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], # images of all the sizes will be squeezed to 150 x 150 image size
    batch_size= BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, lables in train_ds.take(1):  # taking one batch from the dataset

    for i in range(BATCH_SIZE): # looping over one batch

        row = 4

        plt.subplot(row, BATCH_SIZE // 4, i+1) # Access the axis

        plt.grid(False)  # no grid

        plt.imshow(images[i].numpy().astype('uint8'))  # Show image, (convert to numpy and int)

        plt.title(class_names[lables[i]])

    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15,6))

for images, lables in test_ds.take(1):  # taking one batch from the dataset

    for i in range(BATCH_SIZE): # looping over one batch

        row = 4

        plt.subplot(row, BATCH_SIZE // 4, i+1) # Access the axis

        plt.grid(False)  # no grid

        plt.imshow(images[i].numpy().astype('uint8'))  # Show image, (convert to numpy and int)

        plt.title(class_names[lables[i]])

    plt.tight_layout()

plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ##  Random Zoom

# %%
# method in tensorflow to randomly zoom

layer = tf.keras.layers.RandomZoom(height_factor = (-0.2, -0.2), # range for the zooming (given in the form of tuple)
                                   width_factor = (-0.2, -0.2)
                                  )

plt.figure()

img_num = 3

for image, label in test_ds.take(1): # get one batch

    out_img = layer(image)

    plt.subplot(1,2,1)

    plt.title('original')

    plt.imshow(image[img_num].numpy().astype('uint8'))


    plt.subplot(1,2,2)

    plt.title('Zoomed')

    plt.imshow(out_img[img_num].numpy().astype('uint8'))

# %% [markdown]
# ##  Random Rotation

# %%
# applying method to radomly rotate a image

layer = tf.keras.layers.RandomRotation(factor = (-0.2, 0.3),
                                       fill_mode='reflect', #The input is extended by reflecting about the edge of the last pixel.
                                       interpolation='bilinear'
                                      )

plt.figure()

img_num = 3

for image, label in test_ds.take(1): # get one batch

    out_img = layer(image)

    plt.subplot(1,2,1)

    plt.title('original')

    plt.imshow(image[img_num].numpy().astype('uint8'))


    plt.subplot(1,2,2)

    plt.title('Rotated')

    plt.imshow(out_img[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
dor1 = 0.05
dor2 = 0.04
dor3 = 0.04
dor4 = 0.03
dor5 = 0.03
dor6 = 0.02

# %%
# Build model

reg=tf.keras.regularizers.L2(l2=0.05)

initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)


model = tf.keras.Sequential()

model.add(tf.keras.layers.RandomFlip("horizontal_and_vertical"))

model.add(tf.keras.layers.RandomRotation(0.2))

model.add(tf.keras.layers.RandomZoom(height_factor = (-0.2, -0.2),
                                   width_factor = (-0.2, -0.2)))

model.add(tf.keras.layers.Rescaling(1/255.)) # convert between 0 and 1


### ------
### Set 1
### ------



model.add(tf.keras.layers.Conv2D(8, (3,3),kernel_regularizer=reg,kernel_initializer = initializer)) # 188 X 188 X 8

model.add(tf.keras.layers.MaxPool2D(2,2)) # 94 X 94 X 8

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))



### ------
### Set 2
### ------

model.add(tf.keras.layers.Conv2D(16, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 92 X 92 X 16

model.add(tf.keras.layers.MaxPool2D(2,2)) # 46 X 46 X 16

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




### ------
### Set 3
### ------

model.add(tf.keras.layers.Conv2D(32, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 44 X 44 X 632

model.add(tf.keras.layers.MaxPool2D(2,2)) # 22 X 22 X 32

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))



### ------
### Set 4
### ------

model.add(tf.keras.layers.Conv2D(64, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 20 X 20 X 64

model.add(tf.keras.layers.MaxPool2D(2,2)) # 10 X 10 X 64

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))



### ------
### Set 5
### ------

model.add(tf.keras.layers.Conv2D(128, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 8 X 8 X 128

model.add(tf.keras.layers.MaxPool2D(2,2)) # 4 X 4 X 128

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




### ------
### Set 6
### ------

model.add(tf.keras.layers.Conv2D(256, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 2 X 2 X 128

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




### -------------
### Flatten layer
### -------------


model.add(tf.keras.layers.Flatten())



model.add(tf.keras.layers.Dense(256))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




model.add(tf.keras.layers.Dense(64))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




model.add(tf.keras.layers.Dense(32))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


model.add(tf.keras.layers.Dense(5))

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optim = tf.keras.optimizers.Adam(learning_rate=ALPHA)

model.compile(optimizer=optim, loss=loss_fn, metrics=['accuracy'])

# %% [markdown]
# ###  Checkpoint

# %%
filepath=os.path.join(inpDir,subDir, altName)

# %%
# Early stopping callback

es_check_point=tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    min_delta=0,
    patience=PATIENCE,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=False,
)

'''

    When the loss stops decreasin for cycles = parience level, at that time we will reduce the alpha level.
    this is acieved by the ReduceLROnPlateau

'''

# Learning rate decay callback

lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto'
)

model_check_point=tf.keras.callbacks.ModelCheckpoint(
    filepath,
    monitor = 'val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode = 'auto',
)

# %%
history = model.fit(train_ds,
                    validation_data=test_ds,
                    batch_size=BATCH_SIZE,
                    epochs=70,
                    verbose=1,
                    callbacks=[es_check_point, lr, model_check_point]
                   )
# Out:
# Epoch 1/70
# 91/92 [============================>.] - ETA: 0s - loss: 29.1707 - accuracy: 0.4808
# Epoch 1: val_loss improved from inf to 14.31582, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 15s 100ms/step - loss: 29.0415 - accuracy: 0.4813 - val_loss: 14.3158 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 2/70
# 91/92 [============================>.] - ETA: 0s - loss: 8.3595 - accuracy: 0.5519
# Epoch 2: val_loss improved from 14.31582 to 7.02169, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 8.3338 - accuracy: 0.5528 - val_loss: 7.0217 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 3/70
# 90/92 [============================>.] - ETA: 0s - loss: 4.0401 - accuracy: 0.5736
# Epoch 3: val_loss improved from 7.02169 to 4.78030, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 4.0210 - accuracy: 0.5753 - val_loss: 4.7803 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 4/70
# 90/92 [============================>.] - ETA: 0s - loss: 2.6921 - accuracy: 0.5840
# Epoch 4: val_loss improved from 4.78030 to 3.21166, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 2.6842 - accuracy: 0.5851 - val_loss: 3.2117 - val_accuracy: 0.3011 - lr: 0.0010
# Epoch 5/70
# 91/92 [============================>.] - ETA: 0s - loss: 2.1544 - accuracy: 0.5989
# Epoch 5: val_loss improved from 3.21166 to 2.61301, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 28ms/step - loss: 2.1522 - accuracy: 0.5995 - val_loss: 2.6130 - val_accuracy: 0.3678 - lr: 0.0010
# Epoch 6/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.8269 - accuracy: 0.6051
# Epoch 6: val_loss improved from 2.61301 to 2.05831, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 1.8249 - accuracy: 0.6056 - val_loss: 2.0583 - val_accuracy: 0.4360 - lr: 0.0010
# Epoch 7/70
# 92/92 [==============================] - ETA: 0s - loss: 1.6403 - accuracy: 0.6202
# Epoch 7: val_loss improved from 2.05831 to 1.89991, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 1.6403 - accuracy: 0.6202 - val_loss: 1.8999 - val_accuracy: 0.5027 - lr: 0.0010
# Epoch 8/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.5559 - accuracy: 0.6080
# Epoch 8: val_loss improved from 1.89991 to 1.76918, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 1.5523 - accuracy: 0.6097 - val_loss: 1.7692 - val_accuracy: 0.5204 - lr: 0.0010
# Epoch 9/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.4437 - accuracy: 0.6223
# Epoch 9: val_loss did not improve from 1.76918
# 92/92 [==============================] - 2s 27ms/step - loss: 1.4419 - accuracy: 0.6226 - val_loss: 1.7883 - val_accuracy: 0.4510 - lr: 0.0010
# Epoch 10/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.4173 - accuracy: 0.5986
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 1.76918
# 92/92 [==============================] - 3s 30ms/step - loss: 1.4146 - accuracy: 0.6001 - val_loss: 1.7801 - val_accuracy: 0.5163 - lr: 0.0010
# Epoch 11/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.2813 - accuracy: 0.6330
# Epoch 11: val_loss improved from 1.76918 to 1.64124, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 1.2756 - accuracy: 0.6359 - val_loss: 1.6412 - val_accuracy: 0.5082 - lr: 5.0000e-04
# Epoch 12/70
# 92/92 [==============================] - ETA: 0s - loss: 1.2276 - accuracy: 0.6413
# Epoch 12: val_loss improved from 1.64124 to 1.40503, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 1.2276 - accuracy: 0.6413 - val_loss: 1.4050 - val_accuracy: 0.5695 - lr: 5.0000e-04
# Epoch 13/70
# 92/92 [==============================] - ETA: 0s - loss: 1.2207 - accuracy: 0.6352
# Epoch 13: val_loss improved from 1.40503 to 1.32793, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 37ms/step - loss: 1.2207 - accuracy: 0.6352 - val_loss: 1.3279 - val_accuracy: 0.5913 - lr: 5.0000e-04
# Epoch 14/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.1918 - accuracy: 0.6465
# Epoch 14: val_loss did not improve from 1.32793
# 92/92 [==============================] - 3s 30ms/step - loss: 1.1876 - accuracy: 0.6478 - val_loss: 1.3678 - val_accuracy: 0.5899 - lr: 5.0000e-04
# Epoch 15/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.1637 - accuracy: 0.6469
# Epoch 15: val_loss improved from 1.32793 to 1.31292, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 27ms/step - loss: 1.1608 - accuracy: 0.6475 - val_loss: 1.3129 - val_accuracy: 0.6226 - lr: 5.0000e-04
# Epoch 16/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.1856 - accuracy: 0.6358
# Epoch 16: val_loss did not improve from 1.31292
# 92/92 [==============================] - 2s 24ms/step - loss: 1.1833 - accuracy: 0.6373 - val_loss: 2.1058 - val_accuracy: 0.3992 - lr: 5.0000e-04
# Epoch 17/70
# 92/92 [==============================] - ETA: 0s - loss: 1.1599 - accuracy: 0.6434
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 17: val_loss did not improve from 1.31292
# 92/92 [==============================] - 2s 24ms/step - loss: 1.1599 - accuracy: 0.6434 - val_loss: 2.1002 - val_accuracy: 0.4292 - lr: 5.0000e-04
# Epoch 18/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.0884 - accuracy: 0.6717
# Epoch 18: val_loss improved from 1.31292 to 1.14657, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 32ms/step - loss: 1.0861 - accuracy: 0.6723 - val_loss: 1.1466 - val_accuracy: 0.6540 - lr: 2.5000e-04
# Epoch 19/70
# 92/92 [==============================] - ETA: 0s - loss: 1.0521 - accuracy: 0.6822
# Epoch 19: val_loss improved from 1.14657 to 1.09470, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 30ms/step - loss: 1.0521 - accuracy: 0.6822 - val_loss: 1.0947 - val_accuracy: 0.6703 - lr: 2.5000e-04
# Epoch 20/70
# 92/92 [==============================] - ETA: 0s - loss: 1.0423 - accuracy: 0.6809
# Epoch 20: val_loss did not improve from 1.09470
# 92/92 [==============================] - 2s 24ms/step - loss: 1.0423 - accuracy: 0.6809 - val_loss: 1.1653 - val_accuracy: 0.6308 - lr: 2.5000e-04
# Epoch 21/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.0429 - accuracy: 0.6823
# Epoch 21: val_loss improved from 1.09470 to 1.05492, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 1.0403 - accuracy: 0.6832 - val_loss: 1.0549 - val_accuracy: 0.6540 - lr: 2.5000e-04
# Epoch 22/70
# 92/92 [==============================] - ETA: 0s - loss: 1.0188 - accuracy: 0.6809
# Epoch 22: val_loss did not improve from 1.05492
# 92/92 [==============================] - 2s 25ms/step - loss: 1.0188 - accuracy: 0.6809 - val_loss: 1.3838 - val_accuracy: 0.5640 - lr: 2.5000e-04
# Epoch 23/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.0051 - accuracy: 0.6851
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 23: val_loss did not improve from 1.05492
# 92/92 [==============================] - 2s 26ms/step - loss: 1.0033 - accuracy: 0.6856 - val_loss: 1.0687 - val_accuracy: 0.6594 - lr: 2.5000e-04
# Epoch 24/70
# 92/92 [==============================] - ETA: 0s - loss: 0.9547 - accuracy: 0.7108
# Epoch 24: val_loss improved from 1.05492 to 1.00087, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 32ms/step - loss: 0.9547 - accuracy: 0.7108 - val_loss: 1.0009 - val_accuracy: 0.7098 - lr: 1.2500e-04
# Epoch 25/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.9226 - accuracy: 0.7133
# Epoch 25: val_loss improved from 1.00087 to 0.99219, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 0.9211 - accuracy: 0.7139 - val_loss: 0.9922 - val_accuracy: 0.6866 - lr: 1.2500e-04
# Epoch 26/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.9141 - accuracy: 0.7163
# Epoch 26: val_loss improved from 0.99219 to 0.97432, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 0.9111 - accuracy: 0.7173 - val_loss: 0.9743 - val_accuracy: 0.7071 - lr: 1.2500e-04
# Epoch 27/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.9173 - accuracy: 0.7139
# Epoch 27: val_loss improved from 0.97432 to 0.92802, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 0.9130 - accuracy: 0.7163 - val_loss: 0.9280 - val_accuracy: 0.7057 - lr: 1.2500e-04
# Epoch 28/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.8884 - accuracy: 0.7253
# Epoch 28: val_loss did not improve from 0.92802
# 92/92 [==============================] - 2s 26ms/step - loss: 0.8870 - accuracy: 0.7258 - val_loss: 0.9988 - val_accuracy: 0.6826 - lr: 1.2500e-04
# Epoch 29/70
# 92/92 [==============================] - ETA: 0s - loss: 0.8782 - accuracy: 0.7262
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 29: val_loss did not improve from 0.92802
# 92/92 [==============================] - 3s 32ms/step - loss: 0.8782 - accuracy: 0.7262 - val_loss: 1.0804 - val_accuracy: 0.6635 - lr: 1.2500e-04
# Epoch 30/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.8416 - accuracy: 0.7466
# Epoch 30: val_loss did not improve from 0.92802
# 92/92 [==============================] - 2s 27ms/step - loss: 0.8404 - accuracy: 0.7473 - val_loss: 0.9723 - val_accuracy: 0.7016 - lr: 6.2500e-05
# Epoch 31/70
# 92/92 [==============================] - ETA: 0s - loss: 0.8169 - accuracy: 0.7500
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 31: val_loss did not improve from 0.92802
# 92/92 [==============================] - 2s 25ms/step - loss: 0.8169 - accuracy: 0.7500 - val_loss: 0.9405 - val_accuracy: 0.7044 - lr: 6.2500e-05
# Epoch 32/70
# 92/92 [==============================] - ETA: 0s - loss: 0.7934 - accuracy: 0.7599
# Epoch 32: val_loss improved from 0.92802 to 0.89918, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 0.7934 - accuracy: 0.7599 - val_loss: 0.8992 - val_accuracy: 0.7357 - lr: 3.1250e-05
# Epoch 33/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.7692 - accuracy: 0.7760
# Epoch 33: val_loss improved from 0.89918 to 0.88021, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 0.7657 - accuracy: 0.7779 - val_loss: 0.8802 - val_accuracy: 0.7248 - lr: 3.1250e-05
# Epoch 34/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.7544 - accuracy: 0.7795
# Epoch 34: val_loss improved from 0.88021 to 0.86232, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 31ms/step - loss: 0.7537 - accuracy: 0.7793 - val_loss: 0.8623 - val_accuracy: 0.7302 - lr: 3.1250e-05
# Epoch 35/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.7485 - accuracy: 0.7743
# Epoch 35: val_loss did not improve from 0.86232
# 92/92 [==============================] - 2s 26ms/step - loss: 0.7446 - accuracy: 0.7769 - val_loss: 0.8811 - val_accuracy: 0.7248 - lr: 3.1250e-05
# Epoch 36/70
# 92/92 [==============================] - ETA: 0s - loss: 0.7306 - accuracy: 0.7858
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 36: val_loss did not improve from 0.86232
# 92/92 [==============================] - 2s 25ms/step - loss: 0.7306 - accuracy: 0.7858 - val_loss: 0.9065 - val_accuracy: 0.7262 - lr: 3.1250e-05
# Epoch 37/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.7139 - accuracy: 0.7896
# Epoch 37: val_loss did not improve from 0.86232
# 92/92 [==============================] - 2s 25ms/step - loss: 0.7124 - accuracy: 0.7909 - val_loss: 0.8760 - val_accuracy: 0.7343 - lr: 1.5625e-05
# Epoch 38/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6965 - accuracy: 0.8029
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 38: val_loss did not improve from 0.86232
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6952 - accuracy: 0.8031 - val_loss: 0.8766 - val_accuracy: 0.7343 - lr: 1.5625e-05
# Epoch 39/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.8005
# Epoch 39: val_loss did not improve from 0.86232
# 92/92 [==============================] - 3s 31ms/step - loss: 0.6805 - accuracy: 0.8004 - val_loss: 0.8673 - val_accuracy: 0.7221 - lr: 7.8125e-06
# Epoch 40/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.8042
# Epoch 40: val_loss improved from 0.86232 to 0.86028, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 27ms/step - loss: 0.6807 - accuracy: 0.8042 - val_loss: 0.8603 - val_accuracy: 0.7384 - lr: 7.8125e-06
# Epoch 41/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6603 - accuracy: 0.8178
# Epoch 41: val_loss did not improve from 0.86028
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6603 - accuracy: 0.8178 - val_loss: 0.8632 - val_accuracy: 0.7180 - lr: 7.8125e-06
# Epoch 42/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.8110
# Epoch 42: val_loss improved from 0.86028 to 0.85292, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 27ms/step - loss: 0.6655 - accuracy: 0.8110 - val_loss: 0.8529 - val_accuracy: 0.7330 - lr: 7.8125e-06
# Epoch 43/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6614 - accuracy: 0.8128
# Epoch 43: val_loss improved from 0.85292 to 0.85112, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 29ms/step - loss: 0.6609 - accuracy: 0.8130 - val_loss: 0.8511 - val_accuracy: 0.7330 - lr: 7.8125e-06
# Epoch 44/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6494 - accuracy: 0.8178
# Epoch 44: val_loss did not improve from 0.85112
# 92/92 [==============================] - 3s 31ms/step - loss: 0.6494 - accuracy: 0.8178 - val_loss: 0.8587 - val_accuracy: 0.7302 - lr: 7.8125e-06
# Epoch 45/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6483 - accuracy: 0.8159
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 45: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6478 - accuracy: 0.8161 - val_loss: 0.8607 - val_accuracy: 0.7398 - lr: 7.8125e-06
# Epoch 46/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6407 - accuracy: 0.8257
# Epoch 46: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6399 - accuracy: 0.8260 - val_loss: 0.8548 - val_accuracy: 0.7262 - lr: 3.9063e-06
# Epoch 47/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.8267
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 47: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6341 - accuracy: 0.8273 - val_loss: 0.8568 - val_accuracy: 0.7248 - lr: 3.9063e-06
# Epoch 48/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6272 - accuracy: 0.8331
# Epoch 48: val_loss did not improve from 0.85112
# 92/92 [==============================] - 3s 29ms/step - loss: 0.6265 - accuracy: 0.8334 - val_loss: 0.8566 - val_accuracy: 0.7234 - lr: 1.9531e-06
# Epoch 49/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6265 - accuracy: 0.8310
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 49: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6252 - accuracy: 0.8324 - val_loss: 0.8621 - val_accuracy: 0.7248 - lr: 1.9531e-06
# Epoch 50/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.8358
# Epoch 50: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6260 - accuracy: 0.8358 - val_loss: 0.8640 - val_accuracy: 0.7302 - lr: 9.7656e-07
# Epoch 51/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6163 - accuracy: 0.8368
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 51: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6152 - accuracy: 0.8372 - val_loss: 0.8617 - val_accuracy: 0.7289 - lr: 9.7656e-07
# Epoch 52/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.8403
# Epoch 52: val_loss did not improve from 0.85112
# 92/92 [==============================] - 2s 26ms/step - loss: 0.6135 - accuracy: 0.8403 - val_loss: 0.8621 - val_accuracy: 0.7275 - lr: 4.8828e-07
# Epoch 53/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6278 - accuracy: 0.8300Restoring model weights from the end of the best epoch: 43.
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 53: val_loss did not improve from 0.85112
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6271 - accuracy: 0.8300 - val_loss: 0.8618 - val_accuracy: 0.7275 - lr: 4.8828e-07
# Epoch 53: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_18 (RandomFlip  (None, 190, 190, 3)       0
#  )
#
#  random_rotation_34 (Random  (None, 190, 190, 3)       0
#  Rotation)
#
#  random_zoom_17 (RandomZoom  (None, 190, 190, 3)       0
#  )
#
#  rescaling_19 (Rescaling)    (None, 190, 190, 3)       0
#
#  conv2d_99 (Conv2D)          (None, 188, 188, 8)       224
#
#  max_pooling2d_83 (MaxPooli  (None, 94, 94, 8)         0
#  ng2D)
#
#  batch_normalization_118 (B  (None, 94, 94, 8)         32
#  atchNormalization)
#
#  activation_108 (Activation  (None, 94, 94, 8)         0
#  )
#
#  conv2d_100 (Conv2D)         (None, 92, 92, 16)        1168
#
#  max_pooling2d_84 (MaxPooli  (None, 46, 46, 16)        0
#  ng2D)
#
#  batch_normalization_119 (B  (None, 46, 46, 16)        64
#  atchNormalization)
#
#  activation_109 (Activation  (None, 46, 46, 16)        0
#  )
#
#  conv2d_101 (Conv2D)         (None, 44, 44, 32)        4640
#
#  max_pooling2d_85 (MaxPooli  (None, 22, 22, 32)        0
#  ng2D)
#
#  batch_normalization_120 (B  (None, 22, 22, 32)        128
#  atchNormalization)
#
#  activation_110 (Activation  (None, 22, 22, 32)        0
#  )
#
#  conv2d_102 (Conv2D)         (None, 20, 20, 64)        18496
#
#  max_pooling2d_86 (MaxPooli  (None, 10, 10, 64)        0
#  ng2D)
#
#  batch_normalization_121 (B  (None, 10, 10, 64)        256
#  atchNormalization)
#
#  activation_111 (Activation  (None, 10, 10, 64)        0
#  )
#
#  conv2d_103 (Conv2D)         (None, 8, 8, 128)         73856
#
#  max_pooling2d_87 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  batch_normalization_122 (B  (None, 4, 4, 128)         512
#  atchNormalization)
#
#  activation_112 (Activation  (None, 4, 4, 128)         0
#  )
#
#  conv2d_104 (Conv2D)         (None, 2, 2, 256)         295168
#
#  batch_normalization_123 (B  (None, 2, 2, 256)         1024
#  atchNormalization)
#
#  activation_113 (Activation  (None, 2, 2, 256)         0
#  )
#
#  flatten_16 (Flatten)        (None, 1024)              0
#
#  dense_41 (Dense)            (None, 256)               262400
#
#  batch_normalization_124 (B  (None, 256)               1024
#  atchNormalization)
#
#  activation_114 (Activation  (None, 256)               0
#  )
#
#  dense_42 (Dense)            (None, 64)                16448
#
#  batch_normalization_125 (B  (None, 64)                256
#  atchNormalization)
#
#  activation_115 (Activation  (None, 64)                0
#  )
#
#  dense_43 (Dense)            (None, 32)                2080
#
#  batch_normalization_126 (B  (None, 32)                128
#  atchNormalization)
#
#  activation_116 (Activation  (None, 32)                0
#  )
#
#  dense_44 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 678069 (2.59 MB)
# Trainable params: 676357 (2.58 MB)
# Non-trainable params: 1712 (6.69 KB)
# _________________________________________________________________

# %%
res_df = pd.DataFrame(history.history)

plot_tf_hist(res_df)
