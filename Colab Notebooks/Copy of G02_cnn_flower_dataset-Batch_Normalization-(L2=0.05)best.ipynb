# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 23c:
#
# ## MNIST feminist Data
#
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
# Lets import some libraries
import os

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from datetime import datetime, timedelta

from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow as tf

# %matplotlib inline

# %%
physical_devices = tf.config.list_physical_devices('GPU')

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Strictly for tensorflow version 2.12
### To hide bugs throwing warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Some basic parameters

inpDir = '/home/dai/6. DNN/CNN/Flower' # location where input data is stored
outDir = '../output' # location to store outputs
modelDir='../model'
subDir='flower_photos'
altName = 'Grp_2_project'



RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results

EPOCHS = 70  # number of cycles to run

ALPHA = 0.001  # learning rate

TEST_SIZE = 0.2 # What fraction we want to keep for testing

BATCH_SIZE = 32

FACTOR_LR = 0.5

LR_PATIENCE = 2

PATIENCE = 10
IMG_HEIGHT = 190
IMG_WIDTH = 190


# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (12,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }
CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
def fn_plot_label(tr_ds, ts_ds):


    plt.figure(figsize = (15,5))  # instantiate the figure

    # -----------------------------------------------------------------------------------------

    # labels for the training set

    plt.subplot(1,2,1) # first of the 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis = 0).numpy() # get the labels

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color = 'DarkBlue') # barplot the counts

    plt.xticks(range(len(unique)), class_names)

    plt.title('Training set')


    # -----------------------------------------------------------------------------------------

    # labels for the testing set

    plt.subplot(1,2,2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis = 0).numpy()

    unique_tst, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique_tst)), counts, align='center', color = 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Testing set')

# %% [markdown]
# ###  Using Flower dataset

# %% [markdown]
# ## Converting to Datsets  from a directory

# %%
import tensorflow as tf
import pathlib
dataset_url = "http://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,fname = 'flower_photos',untar = True)
data_dir = pathlib.Path(data_dir)

# %%
os.listdir(data_dir)
# Out:
# ['sunflowers', 'daisy', 'dandelion', 'roses', 'tulips', 'LICENSE.txt']

# %%
# Creating training data

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,  # path to the data directory
    validation_split=TEST_SIZE, # What is the ratio of validation data
    subset='training', #purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], # images of all the sizes will be squeezed to 150 x 150 image size
    batch_size= BATCH_SIZE
)

# test data

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,  # path to the data directory
    validation_split=TEST_SIZE, # What is the ratio of validation data
    subset='validation', #purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], # images of all the sizes will be squeezed to 150 x 150 image size
    batch_size= BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(15,6))

for images, lables in train_ds.take(1):  # taking one batch from the dataset

    for i in range(BATCH_SIZE): # looping over one batch

        row = 4

        plt.subplot(row, BATCH_SIZE // 4, i+1) # Access the axis

        plt.grid(False)  # no grid

        plt.imshow(images[i].numpy().astype('uint8'))  # Show image, (convert to numpy and int)

        plt.title(class_names[lables[i]])

    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15,6))

for images, lables in test_ds.take(1):  # taking one batch from the dataset

    for i in range(BATCH_SIZE): # looping over one batch

        row = 4

        plt.subplot(row, BATCH_SIZE // 4, i+1) # Access the axis

        plt.grid(False)  # no grid

        plt.imshow(images[i].numpy().astype('uint8'))  # Show image, (convert to numpy and int)

        plt.title(class_names[lables[i]])

    plt.tight_layout()

plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ##  Random Zoom

# %%
# method in tensorflow to randomly zoom

layer = tf.keras.layers.RandomZoom(height_factor = (-0.2, -0.2), # range for the zooming (given in the form of tuple)
                                   width_factor = (-0.2, -0.2)
                                  )

plt.figure()

img_num = 3

for image, label in test_ds.take(1): # get one batch

    out_img = layer(image)

    plt.subplot(1,2,1)

    plt.title('original')

    plt.imshow(image[img_num].numpy().astype('uint8'))


    plt.subplot(1,2,2)

    plt.title('Zoomed')

    plt.imshow(out_img[img_num].numpy().astype('uint8'))

# %% [markdown]
# ##  Random Rotation

# %%
# applying method to radomly rotate a image

layer = tf.keras.layers.RandomRotation(factor = (-0.2, 0.3),
                                       fill_mode='reflect', #The input is extended by reflecting about the edge of the last pixel.
                                       interpolation='bilinear'
                                      )

plt.figure()

img_num = 3

for image, label in test_ds.take(1): # get one batch

    out_img = layer(image)

    plt.subplot(1,2,1)

    plt.title('original')

    plt.imshow(image[img_num].numpy().astype('uint8'))


    plt.subplot(1,2,2)

    plt.title('Rotated')

    plt.imshow(out_img[img_num].numpy().astype('uint8'))

# %%
train_ds = train_ds.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
# Build model

reg=tf.keras.regularizers.L2(l2=0.05)

initializer = tf.keras.initializers.HeNormal(seed = RANDOM_STATE)


model = tf.keras.Sequential()

model.add(tf.keras.layers.RandomFlip("horizontal_and_vertical"))

model.add(tf.keras.layers.RandomRotation(0.2))

model.add(tf.keras.layers.Rescaling(1/255.)) # convert between 0 and 1


### ------
### Set 1
### ------



model.add(tf.keras.layers.Conv2D(8, (3,3),kernel_regularizer=reg,kernel_initializer = initializer)) # 188 X 188 X 8

model.add(tf.keras.layers.MaxPool2D(2,2)) # 94 X 94 X 8

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))




### ------
### Set 2
### ------

model.add(tf.keras.layers.Conv2D(16, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 92 X 92 X 16

model.add(tf.keras.layers.MaxPool2D(2,2)) # 46 X 46 X 16

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))



### ------
### Set 3
### ------

model.add(tf.keras.layers.Conv2D(32, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 44 X 44 X 632

model.add(tf.keras.layers.MaxPool2D(2,2)) # 22 X 22 X 32

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


### ------
### Set 4
### ------

model.add(tf.keras.layers.Conv2D(64, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 20 X 20 X 64

model.add(tf.keras.layers.MaxPool2D(2,2)) # 10 X 10 X 64

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


### ------
### Set 5
### ------

model.add(tf.keras.layers.Conv2D(128, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 8 X 8 X 128

model.add(tf.keras.layers.MaxPool2D(2,2)) # 4 X 4 X 128

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))



model.add(tf.keras.layers.Conv2D(256, (3,3),
                                kernel_regularizer=reg,kernel_initializer = initializer)) # 2 X 2 X 128

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))

### -------------
### Flatten layer
### -------------


model.add(tf.keras.layers.Flatten())



model.add(tf.keras.layers.Dense(256))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


model.add(tf.keras.layers.Dense(64))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


model.add(tf.keras.layers.Dense(32))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Activation('relu'))


model.add(tf.keras.layers.Dense(5))

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optim = tf.keras.optimizers.Adam(learning_rate=ALPHA)

model.compile(optimizer=optim, loss=loss_fn, metrics=['accuracy'])

# %% [markdown]
# ###  Checkpoint

# %%
filepath=os.path.join(inpDir,subDir, altName)

# %%
# Early stopping callback

es_check_point=tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    min_delta=0,
    patience=PATIENCE,
    verbose=1,
    restore_best_weights=True,
    start_from_epoch=False,
)

'''

    When the loss stops decreasin for cycles = parience level, at that time we will reduce the alpha level.
    this is acieved by the ReduceLROnPlateau

'''

# Learning rate decay callback

lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=FACTOR_LR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto'
)

model_check_point=tf.keras.callbacks.ModelCheckpoint(
    filepath,
    monitor = 'val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode = 'auto',
)

# %%
history = model.fit(train_ds,
                    validation_data=test_ds,
                    batch_size=BATCH_SIZE,
                    epochs=70,
                    verbose=1,
                    callbacks=[es_check_point, lr, model_check_point]
                   )
# Out:
# Epoch 1/70
# 90/92 [============================>.] - ETA: 0s - loss: 30.2089 - accuracy: 0.4517
# Epoch 1: val_loss improved from inf to 14.86413, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 14s 70ms/step - loss: 29.9073 - accuracy: 0.4540 - val_loss: 14.8641 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 2/70
# 91/92 [============================>.] - ETA: 0s - loss: 8.9743 - accuracy: 0.5615
# Epoch 2: val_loss improved from 14.86413 to 6.98414, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 8.9458 - accuracy: 0.5627 - val_loss: 6.9841 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 3/70
# 91/92 [============================>.] - ETA: 0s - loss: 4.3002 - accuracy: 0.5783
# Epoch 3: val_loss improved from 6.98414 to 4.86424, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 27ms/step - loss: 4.2922 - accuracy: 0.5794 - val_loss: 4.8642 - val_accuracy: 0.2507 - lr: 0.0010
# Epoch 4/70
# 92/92 [==============================] - ETA: 0s - loss: 2.8484 - accuracy: 0.5800
# Epoch 4: val_loss improved from 4.86424 to 3.94143, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 2.8484 - accuracy: 0.5800 - val_loss: 3.9414 - val_accuracy: 0.2398 - lr: 0.0010
# Epoch 5/70
# 91/92 [============================>.] - ETA: 0s - loss: 2.1912 - accuracy: 0.6065
# Epoch 5: val_loss improved from 3.94143 to 3.29140, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 2.1891 - accuracy: 0.6073 - val_loss: 3.2914 - val_accuracy: 0.2466 - lr: 0.0010
# Epoch 6/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.8410 - accuracy: 0.6192
# Epoch 6: val_loss improved from 3.29140 to 2.85224, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 1.8396 - accuracy: 0.6189 - val_loss: 2.8522 - val_accuracy: 0.2752 - lr: 0.0010
# Epoch 7/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.6901 - accuracy: 0.6037
# Epoch 7: val_loss improved from 2.85224 to 2.54049, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 1.6874 - accuracy: 0.6046 - val_loss: 2.5405 - val_accuracy: 0.4183 - lr: 0.0010
# Epoch 8/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.5575 - accuracy: 0.6250
# Epoch 8: val_loss improved from 2.54049 to 2.37758, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 1.5570 - accuracy: 0.6257 - val_loss: 2.3776 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 9/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.4384 - accuracy: 0.6408
# Epoch 9: val_loss improved from 2.37758 to 1.71036, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 27ms/step - loss: 1.4361 - accuracy: 0.6420 - val_loss: 1.7104 - val_accuracy: 0.5300 - lr: 0.0010
# Epoch 10/70
# 92/92 [==============================] - ETA: 0s - loss: 1.4029 - accuracy: 0.6301
# Epoch 10: val_loss did not improve from 1.71036
# 92/92 [==============================] - 2s 26ms/step - loss: 1.4029 - accuracy: 0.6301 - val_loss: 2.3419 - val_accuracy: 0.3106 - lr: 0.0010
# Epoch 11/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.3573 - accuracy: 0.6319
# Epoch 11: val_loss improved from 1.71036 to 1.60132, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 1.3529 - accuracy: 0.6335 - val_loss: 1.6013 - val_accuracy: 0.4632 - lr: 0.0010
# Epoch 12/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.3163 - accuracy: 0.6326
# Epoch 12: val_loss improved from 1.60132 to 1.43655, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 1.3120 - accuracy: 0.6339 - val_loss: 1.4365 - val_accuracy: 0.5940 - lr: 0.0010
# Epoch 13/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.2673 - accuracy: 0.6319
# Epoch 13: val_loss did not improve from 1.43655
# 92/92 [==============================] - 2s 22ms/step - loss: 1.2663 - accuracy: 0.6322 - val_loss: 1.6426 - val_accuracy: 0.5095 - lr: 0.0010
# Epoch 14/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.2560 - accuracy: 0.6253
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: val_loss did not improve from 1.43655
# 92/92 [==============================] - 2s 22ms/step - loss: 1.2543 - accuracy: 0.6267 - val_loss: 1.5016 - val_accuracy: 0.5163 - lr: 0.0010
# Epoch 15/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.1567 - accuracy: 0.6514
# Epoch 15: val_loss improved from 1.43655 to 1.38266, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 29ms/step - loss: 1.1553 - accuracy: 0.6512 - val_loss: 1.3827 - val_accuracy: 0.5341 - lr: 5.0000e-04
# Epoch 16/70
# 90/92 [============================>.] - ETA: 0s - loss: 1.1123 - accuracy: 0.6656
# Epoch 16: val_loss did not improve from 1.38266
# 92/92 [==============================] - 2s 23ms/step - loss: 1.1077 - accuracy: 0.6669 - val_loss: 1.4955 - val_accuracy: 0.4877 - lr: 5.0000e-04
# Epoch 17/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.0926 - accuracy: 0.6666
# Epoch 17: val_loss improved from 1.38266 to 1.20756, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 23ms/step - loss: 1.0907 - accuracy: 0.6676 - val_loss: 1.2076 - val_accuracy: 0.6376 - lr: 5.0000e-04
# Epoch 18/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.0814 - accuracy: 0.6593
# Epoch 18: val_loss did not improve from 1.20756
# 92/92 [==============================] - 2s 22ms/step - loss: 1.0804 - accuracy: 0.6604 - val_loss: 1.6038 - val_accuracy: 0.4537 - lr: 5.0000e-04
# Epoch 19/70
# 91/92 [============================>.] - ETA: 0s - loss: 1.0831 - accuracy: 0.6621
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_loss did not improve from 1.20756
# 92/92 [==============================] - 2s 22ms/step - loss: 1.0812 - accuracy: 0.6625 - val_loss: 1.2460 - val_accuracy: 0.5790 - lr: 5.0000e-04
# Epoch 20/70
# 92/92 [==============================] - ETA: 0s - loss: 1.0024 - accuracy: 0.6975
# Epoch 20: val_loss did not improve from 1.20756
# 92/92 [==============================] - 3s 27ms/step - loss: 1.0024 - accuracy: 0.6975 - val_loss: 1.4125 - val_accuracy: 0.5177 - lr: 2.5000e-04
# Epoch 21/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.9671 - accuracy: 0.7038
# Epoch 21: val_loss improved from 1.20756 to 1.05542, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 0.9648 - accuracy: 0.7044 - val_loss: 1.0554 - val_accuracy: 0.6812 - lr: 2.5000e-04
# Epoch 22/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.9522 - accuracy: 0.7009
# Epoch 22: val_loss did not improve from 1.05542
# 92/92 [==============================] - 2s 22ms/step - loss: 0.9509 - accuracy: 0.7010 - val_loss: 1.0784 - val_accuracy: 0.6662 - lr: 2.5000e-04
# Epoch 23/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.9525 - accuracy: 0.7091
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 23: val_loss did not improve from 1.05542
# 92/92 [==============================] - 2s 22ms/step - loss: 0.9503 - accuracy: 0.7101 - val_loss: 1.0635 - val_accuracy: 0.6866 - lr: 2.5000e-04
# Epoch 24/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.8987 - accuracy: 0.7263
# Epoch 24: val_loss improved from 1.05542 to 1.01757, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 23ms/step - loss: 0.8967 - accuracy: 0.7268 - val_loss: 1.0176 - val_accuracy: 0.6689 - lr: 1.2500e-04
# Epoch 25/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.8721 - accuracy: 0.7318
# Epoch 25: val_loss improved from 1.01757 to 0.95366, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.8708 - accuracy: 0.7319 - val_loss: 0.9537 - val_accuracy: 0.6989 - lr: 1.2500e-04
# Epoch 26/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.8615 - accuracy: 0.7292
# Epoch 26: val_loss improved from 0.95366 to 0.94549, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 30ms/step - loss: 0.8581 - accuracy: 0.7309 - val_loss: 0.9455 - val_accuracy: 0.7030 - lr: 1.2500e-04
# Epoch 27/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.8482 - accuracy: 0.7424
# Epoch 27: val_loss improved from 0.94549 to 0.92772, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 26ms/step - loss: 0.8447 - accuracy: 0.7449 - val_loss: 0.9277 - val_accuracy: 0.7098 - lr: 1.2500e-04
# Epoch 28/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.8365 - accuracy: 0.7428
# Epoch 28: val_loss improved from 0.92772 to 0.91953, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 28ms/step - loss: 0.8354 - accuracy: 0.7435 - val_loss: 0.9195 - val_accuracy: 0.7193 - lr: 1.2500e-04
# Epoch 29/70
# 92/92 [==============================] - ETA: 0s - loss: 0.8231 - accuracy: 0.7520
# Epoch 29: val_loss did not improve from 0.91953
# 92/92 [==============================] - 2s 24ms/step - loss: 0.8231 - accuracy: 0.7520 - val_loss: 0.9376 - val_accuracy: 0.7207 - lr: 1.2500e-04
# Epoch 30/70
# 92/92 [==============================] - ETA: 0s - loss: 0.8190 - accuracy: 0.7602
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 30: val_loss did not improve from 0.91953
# 92/92 [==============================] - 2s 24ms/step - loss: 0.8190 - accuracy: 0.7602 - val_loss: 0.9214 - val_accuracy: 0.7234 - lr: 1.2500e-04
# Epoch 31/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.7701 - accuracy: 0.7716
# Epoch 31: val_loss did not improve from 0.91953
# 92/92 [==============================] - 2s 26ms/step - loss: 0.7688 - accuracy: 0.7718 - val_loss: 0.9346 - val_accuracy: 0.7071 - lr: 6.2500e-05
# Epoch 32/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.7563 - accuracy: 0.7764
# Epoch 32: val_loss improved from 0.91953 to 0.84841, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.7546 - accuracy: 0.7776 - val_loss: 0.8484 - val_accuracy: 0.7493 - lr: 6.2500e-05
# Epoch 33/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.7878
# Epoch 33: val_loss did not improve from 0.84841
# 92/92 [==============================] - 2s 22ms/step - loss: 0.7242 - accuracy: 0.7888 - val_loss: 0.9209 - val_accuracy: 0.7166 - lr: 6.2500e-05
# Epoch 34/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.7183 - accuracy: 0.7909
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 34: val_loss did not improve from 0.84841
# 92/92 [==============================] - 2s 22ms/step - loss: 0.7167 - accuracy: 0.7919 - val_loss: 0.8657 - val_accuracy: 0.7507 - lr: 6.2500e-05
# Epoch 35/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6851 - accuracy: 0.7997
# Epoch 35: val_loss improved from 0.84841 to 0.80881, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6825 - accuracy: 0.8011 - val_loss: 0.8088 - val_accuracy: 0.7643 - lr: 3.1250e-05
# Epoch 36/70
# 92/92 [==============================] - ETA: 0s - loss: 0.6693 - accuracy: 0.8151
# Epoch 36: val_loss did not improve from 0.80881
# 92/92 [==============================] - 2s 27ms/step - loss: 0.6693 - accuracy: 0.8151 - val_loss: 0.8090 - val_accuracy: 0.7561 - lr: 3.1250e-05
# Epoch 37/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.8087
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 37: val_loss did not improve from 0.80881
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6665 - accuracy: 0.8106 - val_loss: 0.8095 - val_accuracy: 0.7711 - lr: 3.1250e-05
# Epoch 38/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6418 - accuracy: 0.8249
# Epoch 38: val_loss improved from 0.80881 to 0.78176, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.6400 - accuracy: 0.8256 - val_loss: 0.7818 - val_accuracy: 0.7616 - lr: 1.5625e-05
# Epoch 39/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6284 - accuracy: 0.8242
# Epoch 39: val_loss improved from 0.78176 to 0.76826, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.6270 - accuracy: 0.8253 - val_loss: 0.7683 - val_accuracy: 0.7684 - lr: 1.5625e-05
# Epoch 40/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.6114 - accuracy: 0.8345
# Epoch 40: val_loss improved from 0.76826 to 0.76528, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.6102 - accuracy: 0.8355 - val_loss: 0.7653 - val_accuracy: 0.7820 - lr: 1.5625e-05
# Epoch 41/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.6046 - accuracy: 0.8337
# Epoch 41: val_loss improved from 0.76528 to 0.75848, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 25ms/step - loss: 0.6019 - accuracy: 0.8355 - val_loss: 0.7585 - val_accuracy: 0.7820 - lr: 1.5625e-05
# Epoch 42/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5976 - accuracy: 0.8389
# Epoch 42: val_loss improved from 0.75848 to 0.75039, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 3s 29ms/step - loss: 0.5959 - accuracy: 0.8396 - val_loss: 0.7504 - val_accuracy: 0.7793 - lr: 1.5625e-05
# Epoch 43/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5996 - accuracy: 0.8355
# Epoch 43: val_loss did not improve from 0.75039
# 92/92 [==============================] - 2s 23ms/step - loss: 0.5975 - accuracy: 0.8369 - val_loss: 0.7569 - val_accuracy: 0.7752 - lr: 1.5625e-05
# Epoch 44/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.5892 - accuracy: 0.8406
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 44: val_loss did not improve from 0.75039
# 92/92 [==============================] - 2s 23ms/step - loss: 0.5865 - accuracy: 0.8420 - val_loss: 0.7638 - val_accuracy: 0.7820 - lr: 1.5625e-05
# Epoch 45/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5835 - accuracy: 0.8403
# Epoch 45: val_loss improved from 0.75039 to 0.74693, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.5813 - accuracy: 0.8416 - val_loss: 0.7469 - val_accuracy: 0.7861 - lr: 7.8125e-06
# Epoch 46/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5579 - accuracy: 0.8565
# Epoch 46: val_loss did not improve from 0.74693
# 92/92 [==============================] - 2s 24ms/step - loss: 0.5559 - accuracy: 0.8576 - val_loss: 0.7496 - val_accuracy: 0.7807 - lr: 7.8125e-06
# Epoch 47/70
# 92/92 [==============================] - ETA: 0s - loss: 0.5507 - accuracy: 0.8583
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 47: val_loss did not improve from 0.74693
# 92/92 [==============================] - 2s 26ms/step - loss: 0.5507 - accuracy: 0.8583 - val_loss: 0.7497 - val_accuracy: 0.7834 - lr: 7.8125e-06
# Epoch 48/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.5440 - accuracy: 0.8628
# Epoch 48: val_loss improved from 0.74693 to 0.74411, saving model to /home/dai/6. DNN/CNN/Flower/flower_photos/Grp_2_project
# 92/92 [==============================] - 2s 24ms/step - loss: 0.5419 - accuracy: 0.8644 - val_loss: 0.7441 - val_accuracy: 0.7902 - lr: 3.9063e-06
# Epoch 49/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5425 - accuracy: 0.8633
# Epoch 49: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 22ms/step - loss: 0.5411 - accuracy: 0.8641 - val_loss: 0.7444 - val_accuracy: 0.7916 - lr: 3.9063e-06
# Epoch 50/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.8668
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 50: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 23ms/step - loss: 0.5367 - accuracy: 0.8678 - val_loss: 0.7504 - val_accuracy: 0.7820 - lr: 3.9063e-06
# Epoch 51/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5316 - accuracy: 0.8664
# Epoch 51: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 24ms/step - loss: 0.5305 - accuracy: 0.8668 - val_loss: 0.7508 - val_accuracy: 0.7834 - lr: 1.9531e-06
# Epoch 52/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.5428 - accuracy: 0.8597
# Epoch 52: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 52: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 26ms/step - loss: 0.5403 - accuracy: 0.8610 - val_loss: 0.7504 - val_accuracy: 0.7875 - lr: 1.9531e-06
# Epoch 53/70
# 90/92 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.8639
# Epoch 53: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 25ms/step - loss: 0.5381 - accuracy: 0.8648 - val_loss: 0.7531 - val_accuracy: 0.7888 - lr: 9.7656e-07
# Epoch 54/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.8650
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 54: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 22ms/step - loss: 0.5327 - accuracy: 0.8655 - val_loss: 0.7495 - val_accuracy: 0.7875 - lr: 9.7656e-07
# Epoch 55/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5332 - accuracy: 0.8654
# Epoch 55: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 23ms/step - loss: 0.5315 - accuracy: 0.8665 - val_loss: 0.7497 - val_accuracy: 0.7875 - lr: 4.8828e-07
# Epoch 56/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5332 - accuracy: 0.8671
# Epoch 56: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 56: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 22ms/step - loss: 0.5321 - accuracy: 0.8675 - val_loss: 0.7495 - val_accuracy: 0.7861 - lr: 4.8828e-07
# Epoch 57/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5290 - accuracy: 0.8733
# Epoch 57: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 24ms/step - loss: 0.5277 - accuracy: 0.8743 - val_loss: 0.7499 - val_accuracy: 0.7875 - lr: 2.4414e-07
# Epoch 58/70
# 91/92 [============================>.] - ETA: 0s - loss: 0.5334 - accuracy: 0.8654Restoring model weights from the end of the best epoch: 48.
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 58: val_loss did not improve from 0.74411
# 92/92 [==============================] - 2s 27ms/step - loss: 0.5321 - accuracy: 0.8658 - val_loss: 0.7496 - val_accuracy: 0.7888 - lr: 2.4414e-07
# Epoch 58: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_11 (RandomFlip  (None, 190, 190, 3)       0
#  )
#
#  random_rotation_23 (Random  (None, 190, 190, 3)       0
#  Rotation)
#
#  rescaling_12 (Rescaling)    (None, 190, 190, 3)       0
#
#  conv2d_72 (Conv2D)          (None, 188, 188, 8)       224
#
#  max_pooling2d_60 (MaxPooli  (None, 94, 94, 8)         0
#  ng2D)
#
#  batch_normalization_79 (Ba  (None, 94, 94, 8)         32
#  tchNormalization)
#
#  activation_69 (Activation)  (None, 94, 94, 8)         0
#
#  conv2d_73 (Conv2D)          (None, 92, 92, 16)        1168
#
#  max_pooling2d_61 (MaxPooli  (None, 46, 46, 16)        0
#  ng2D)
#
#  batch_normalization_80 (Ba  (None, 46, 46, 16)        64
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 46, 46, 16)        0
#
#  conv2d_74 (Conv2D)          (None, 44, 44, 32)        4640
#
#  max_pooling2d_62 (MaxPooli  (None, 22, 22, 32)        0
#  ng2D)
#
#  batch_normalization_81 (Ba  (None, 22, 22, 32)        128
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 22, 22, 32)        0
#
#  conv2d_75 (Conv2D)          (None, 20, 20, 64)        18496
#
#  max_pooling2d_63 (MaxPooli  (None, 10, 10, 64)        0
#  ng2D)
#
#  batch_normalization_82 (Ba  (None, 10, 10, 64)        256
#  tchNormalization)
#
#  activation_72 (Activation)  (None, 10, 10, 64)        0
#
#  conv2d_76 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_64 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  batch_normalization_83 (Ba  (None, 4, 4, 128)         512
#  tchNormalization)
#
#  activation_73 (Activation)  (None, 4, 4, 128)         0
#
#  conv2d_77 (Conv2D)          (None, 2, 2, 256)         295168
#
#  batch_normalization_84 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 2, 2, 256)         0
#
#  flatten_12 (Flatten)        (None, 1024)              0
#
#  dense_25 (Dense)            (None, 256)               262400
#
#  batch_normalization_85 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  activation_75 (Activation)  (None, 256)               0
#
#  dense_26 (Dense)            (None, 64)                16448
#
#  batch_normalization_86 (Ba  (None, 64)                256
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 64)                0
#
#  dense_27 (Dense)            (None, 32)                2080
#
#  batch_normalization_87 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_77 (Activation)  (None, 32)                0
#
#  dense_28 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 678069 (2.59 MB)
# Trainable params: 676357 (2.58 MB)
# Non-trainable params: 1712 (6.69 KB)
# _________________________________________________________________

# %%
res_df = pd.DataFrame(history.history)

plot_tf_hist(res_df)
