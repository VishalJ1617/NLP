# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 19
#
# ### Simple RNN
#
# Changes for the Assignment
#
# - Tensorflow
# - **Weather History Dataset**
# - One hidden layer
# - ${Tanh}$ activation function
# - **multi-class**
# - ADAM
# - Mini Batch
# - L2 regularization
# - ${Swish}$ Activation function
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from collections.abc import Callable
from typing import Literal

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
###----------------
### Some parameters
###----------------

inpDir = '../input'
outDir = '../output'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 200 # number of epochs
ALPHA = 0.01 # learning rate
NUM_SAMPLES = 1280 # How many samples we want to generate 
NOISE = 0.2 # Noise to be introduced in the data
TEST_SIZE = 0.2
TRAIN_SIZE = 14496 # Fix size of train set so that we have batches of same size
BATCH_SIZE = 32

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %% [markdown]
# ### Dataset
# ##### - Weather History

# %%
data_df=pd.read_csv('weatherHistory.csv')

# %%
data_df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1015.13       Partly cloudy throughout the day.
# 1                   1015.63       Partly cloudy throughout the day.
# 2                   1015.94       Partly cloudy throughout the day.
# 3                   1016.41       Partly cloudy throughout the day.
# 4                   1016.51       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'],utc=True)

# %%
data_df.drop('Formatted Date',axis=1,inplace=True)

# %%
data_df
# Out:
#              Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      Partly Cloudy        rain         9.472222                  7.388889
# 1      Partly Cloudy        rain         9.355556                  7.227778
# 2      Mostly Cloudy        rain         9.377778                  9.377778
# 3      Partly Cloudy        rain         8.288889                  5.944444
# 4      Mostly Cloudy        rain         8.755556                  6.977778
# ...              ...         ...              ...                       ...
# 96448  Partly Cloudy        rain        26.016667                 26.016667
# 96449  Partly Cloudy        rain        24.583333                 24.583333
# 96450  Partly Cloudy        rain        22.038889                 22.038889
# 96451  Partly Cloudy        rain        21.522222                 21.522222
# 96452  Partly Cloudy        rain        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0          0.89            14.1197                   251.0          15.8263
# 1          0.86            14.2646                   259.0          15.8263
# 2          0.89             3.9284                   204.0          14.9569
# 3          0.83            14.1036                   269.0          15.8263
# 4          0.83            11.0446                   259.0          15.8263
# ...         ...                ...                     ...              ...
# 96448      0.43            10.9963                    31.0          16.1000
# 96449      0.48            10.0947                    20.0          15.5526
# 96450      0.56             8.9838                    30.0          16.1000
# 96451      0.60            10.5294                    20.0          16.1000
# 96452      0.61             5.8765                    39.0          15.5204
#
#        Loud Cover  Pressure (millibars)  \
# 0             0.0               1015.13
# 1             0.0               1015.63
# 2             0.0               1015.94
# 3             0.0               1016.41
# 4             0.0               1016.51
# ...           ...                   ...
# 96448         0.0               1014.36
# 96449         0.0               1015.16
# 96450         0.0               1015.66
# 96451         0.0               1015.95
# 96452         0.0               1016.16
#
#                                 Daily Summary                  datetime
# 0           Partly cloudy throughout the day. 2006-03-31 22:00:00+00:00
# 1           Partly cloudy throughout the day. 2006-03-31 23:00:00+00:00
# 2           Partly cloudy throughout the day. 2006-04-01 00:00:00+00:00
# 3           Partly cloudy throughout the day. 2006-04-01 01:00:00+00:00
# 4           Partly cloudy throughout the day. 2006-04-01 02:00:00+00:00
# ...                                       ...                       ...
# 96448  Partly cloudy starting in the morning. 2016-09-09 17:00:00+00:00
# 96449  Partly cloudy starting in the morning. 2016-09-09 18:00:00+00:00
# 96450  Partly cloudy starting in the morning. 2016-09-09 19:00:00+00:00
# 96451  Partly cloudy starting in the morning. 2016-09-09 20:00:00+00:00
# 96452  Partly cloudy starting in the morning. 2016-09-09 21:00:00+00:00
#
# [96453 rows x 12 columns]

# %%
plt.plot(data_df['datetime']);

# %%
fig, ax = plt.subplots(figsize = (15,12))
data_df.plot(x='datetime', y='Temperature (C)', style=".", ax = ax);
ax.grid()

# %%
temp_df = data_df[['datetime','Temperature (C)']]
temp_df = temp_df.sort_values(by='datetime',axis=0,ascending=True)
temp_df = temp_df.reset_index(drop=True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df.reset_index(drop=True, inplace = True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df = temp_df.iloc[1:,:]

# %%
temp_df
# Out:
#                        datetime  Temperature (C)
# 1     2006-01-01 00:00:00+00:00         1.161111
# 2     2006-01-01 01:00:00+00:00         1.666667
# 3     2006-01-01 02:00:00+00:00         1.711111
# 4     2006-01-01 03:00:00+00:00         1.183333
# 5     2006-01-01 04:00:00+00:00         1.205556
# ...                         ...              ...
# 96448 2016-12-31 18:00:00+00:00         0.488889
# 96449 2016-12-31 19:00:00+00:00         0.072222
# 96450 2016-12-31 20:00:00+00:00        -0.233333
# 96451 2016-12-31 21:00:00+00:00        -0.472222
# 96452 2016-12-31 22:00:00+00:00        -0.677778
#
# [96452 rows x 2 columns]

# %%
temp_df.head(25)
# Out:
#                     datetime  Temperature (C)
# 1  2006-01-01 00:00:00+00:00         1.161111
# 2  2006-01-01 01:00:00+00:00         1.666667
# 3  2006-01-01 02:00:00+00:00         1.711111
# 4  2006-01-01 03:00:00+00:00         1.183333
# 5  2006-01-01 04:00:00+00:00         1.205556
# 6  2006-01-01 05:00:00+00:00         2.222222
# 7  2006-01-01 06:00:00+00:00         2.072222
# 8  2006-01-01 07:00:00+00:00         2.200000
# 9  2006-01-01 08:00:00+00:00         2.733333
# 10 2006-01-01 09:00:00+00:00         2.788889
# 11 2006-01-01 10:00:00+00:00         3.822222
# 12 2006-01-01 11:00:00+00:00         4.911111
# 13 2006-01-01 12:00:00+00:00         6.205556
# 14 2006-01-01 13:00:00+00:00         7.438889
# 15 2006-01-01 14:00:00+00:00         6.950000
# 16 2006-01-01 15:00:00+00:00         5.972222
# 17 2006-01-01 16:00:00+00:00         5.905556
# 18 2006-01-01 17:00:00+00:00         4.955556
# 19 2006-01-01 18:00:00+00:00         5.472222
# 20 2006-01-01 19:00:00+00:00         5.972222
# 21 2006-01-01 20:00:00+00:00         4.933333
# 22 2006-01-01 21:00:00+00:00         5.472222
# 23 2006-01-01 22:00:00+00:00         5.422222
# 24 2006-01-01 23:00:00+00:00         5.422222
# 25 2006-01-02 00:00:00+00:00         2.350000

# %%
96452/24
# Out:
# 4018.8333333333335

# %%
4018*24
# Out:
# 96432

# %%
96452-96432
# Out:
# 20

# %%
temp_df = temp_df.iloc[:96432,:]

# %%
temp_df.head(25)
# Out:
#                     datetime  Temperature (C)
# 1  2006-01-01 00:00:00+00:00         1.161111
# 2  2006-01-01 01:00:00+00:00         1.666667
# 3  2006-01-01 02:00:00+00:00         1.711111
# 4  2006-01-01 03:00:00+00:00         1.183333
# 5  2006-01-01 04:00:00+00:00         1.205556
# 6  2006-01-01 05:00:00+00:00         2.222222
# 7  2006-01-01 06:00:00+00:00         2.072222
# 8  2006-01-01 07:00:00+00:00         2.200000
# 9  2006-01-01 08:00:00+00:00         2.733333
# 10 2006-01-01 09:00:00+00:00         2.788889
# 11 2006-01-01 10:00:00+00:00         3.822222
# 12 2006-01-01 11:00:00+00:00         4.911111
# 13 2006-01-01 12:00:00+00:00         6.205556
# 14 2006-01-01 13:00:00+00:00         7.438889
# 15 2006-01-01 14:00:00+00:00         6.950000
# 16 2006-01-01 15:00:00+00:00         5.972222
# 17 2006-01-01 16:00:00+00:00         5.905556
# 18 2006-01-01 17:00:00+00:00         4.955556
# 19 2006-01-01 18:00:00+00:00         5.472222
# 20 2006-01-01 19:00:00+00:00         5.972222
# 21 2006-01-01 20:00:00+00:00         4.933333
# 22 2006-01-01 21:00:00+00:00         5.472222
# 23 2006-01-01 22:00:00+00:00         5.422222
# 24 2006-01-01 23:00:00+00:00         5.422222
# 25 2006-01-02 00:00:00+00:00         2.350000

# %%
final_df = temp_df['Temperature (C)'].to_numpy()

# %%
final_df.shape
# Out:
# (96432,)

# %%
final_df = final_df.reshape(4018,24)

# %%
final_df.shape
# Out:
# (4018, 24)

# %%
final_df = pd.DataFrame(final_df)

# %%
final_df['target'] = final_df[23]

# %%
final_df.drop(23,inplace=True, axis=1)

# %%
final_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     1
#  15  15      4018 non-null   float64
#  16  16      4018 non-null   float64
#  17  17      4018 non-null   float64
#  18  18      4018 non-null   float64
#  19  19      4018 non-null   float64
#  20  20      4018 non-null   float64
#  21  21      4018 non-null   float64
#  22  22      4018 non-null   float64
#  23  target  4018 non-null   float64
# dtypes: float64(24)
# memory usage: 753.5 KB

# %%
features_df = final_df.drop('target',axis=1)
label_df = final_df['target']

# %%
features_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.161111  1.666667  1.711111  1.183333  1.205556  2.222222  2.072222
# 1  2.350000  5.422222  5.905556  5.966667  5.950000  5.950000  6.733333
# 2  1.733333  1.666667  1.666667  1.716667  2.200000  2.200000  2.205556
# 3  1.700000  1.716667  1.716667  1.716667  2.200000  2.200000  2.138889
# 4  2.633333  1.688889  1.161111  1.216667  1.161111  1.161111  2.138889
#
#          7         8         9   ...        13        14        15        16  \
# 0  2.200000  2.733333  2.788889  ...  7.438889  6.950000  5.972222  5.905556
# 1  5.927778  6.944444  6.944444  ...  7.016667  7.016667  6.538889  5.933333
# 2  2.200000  2.222222  2.788889  ...  2.850000  2.827778  2.844444  2.777778
# 3  2.177778  2.200000  2.266667  ...  2.316667  2.800000  2.811111  2.755556
# 4  2.177778  2.222222  2.694444  ...  3.866667  3.866667  3.883333  3.866667
#
#          17        18        19        20        21        22
# 0  4.955556  5.472222  5.972222  4.933333  5.472222  5.422222
# 1  4.866667  3.944444  2.855556  2.805556  2.311111  1.694444
# 2  2.244444  2.355556  2.244444  2.244444  2.255556  2.200000
# 3  2.755556  2.738889  2.733333  2.222222  2.233333  1.666667
# 4  3.938889  3.838889  2.827778  3.288889  2.727778  2.294444
#
# [5 rows x 23 columns]

# %%
#features_df = np.reshape(features_df,(4018,23,1))
#features_df.shape
# Out:
# (4018, 23, 1)

# %% [markdown]
# features_df = final_df.drop('target',axis=1)
# label_df = final_df['target']
# features_df.shape, label_df.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(features_df, label_df, train_size=0.7, shuffle=False)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2812, 23), (1206, 23), (2812,), (1206,))

# %% [markdown]
# ###  Preparing Model

# %%
h_units = 64

input_shape = (23,1)

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.SimpleRNN(units = h_units,
                                  input_shape = input_shape,
                                  activation = 'tanh',))

model.add(tf.keras.layers.Dense(units=1,
                               activation='linear'))

# %%
model.compile(optimizer='adam',loss='mean_squared_error', metrics=['accuracy'])

# %%
model_fit = model.fit(X_train,y_train, 
                      batch_size=32, 
                      epochs=100, 
                      verbose=1, 
                      validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 88/88 [==============================] - 2s 14ms/step - loss: 68.9426 - accuracy: 0.0032 - val_loss: 17.1612 - val_accuracy: 0.0025
# Epoch 2/100
# 88/88 [==============================] - 1s 12ms/step - loss: 16.9854 - accuracy: 0.0032 - val_loss: 6.1185 - val_accuracy: 0.0025
# Epoch 3/100
# 88/88 [==============================] - 1s 12ms/step - loss: 8.0488 - accuracy: 0.0043 - val_loss: 2.7918 - val_accuracy: 0.0025
# Epoch 4/100
100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5901 - accuracy: 0.0039 - val_loss: 0.4589 - val_accuracy: 0.0025
# Epoch 31/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5807 - accuracy: 0.0039 - val_loss: 0.4361 - val_accuracy: 0.0025
# Epoch 32/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5678 - accuracy: 0.0036 - val_loss: 0.4085 - val_accuracy: 0.0025
# Epoch 33/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5833 - accuracy: 0.0043 - val_loss: 0.4436 - val_accuracy: 0.0025
# Epoch 34/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5628 - accuracy: 0.0043 - val_loss: 0.4331 - val_accuracy: 0.0025
# Epoch 35/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5651 - accuracy: 0.0050 - val_loss: 0.4664 - val_accuracy: 0.0025
# Epoch 36/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5694 - accuracy: 0.0046 - val_loss: 0.4214 - val_accuracy: 0.0025
# Epoch 37/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5625 - accuracy: 0.0039 - val_loss: 0.4162 - val_accuracy: 0.0025
# Epoch 38/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5609 - accuracy: 0.0043 - val_loss: 0.4071 - val_accuracy: 0.0025
# Epoch 39/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5577 - accuracy: 0.0046 - val_loss: 0.4031 - val_accuracy: 0.0025
# Epoch 40/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5586 - accuracy: 0.0046 - val_loss: 0.4170 - val_accuracy: 0.0025
# Epoch 41/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5554 - accuracy: 0.0046 - val_loss: 0.4301 - val_accuracy: 0.0025
# Epoch 42/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5629 - accuracy: 0.0046 - val_loss: 0.4110 - val_accuracy: 0.0025
# Epoch 43/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5581 - accuracy: 0.0043 - val_loss: 0.4331 - val_accuracy: 0.0025
# Epoch 44/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5557 - accuracy: 0.0043 - val_loss: 0.4219 - val_accuracy: 0.0025
# Epoch 45/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5521 - accuracy: 0.0046 - val_loss: 0.4222 - val_accuracy: 0.0025
# Epoch 46/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5586 - accuracy: 0.0043 - val_loss: 0.4468 - val_accuracy: 0.0025
# Epoch 47/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5454 - accuracy: 0.0046 - val_loss: 0.4365 - val_accuracy: 0.0025
# Epoch 48/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5612 - accuracy: 0.0043 - val_loss: 0.4287 - val_accuracy: 0.0025
# Epoch 49/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5638 - accuracy: 0.0039 - val_loss: 0.4366 - val_accuracy: 0.0025
# Epoch 50/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5527 - accuracy: 0.0046 - val_loss: 0.4261 - val_accuracy: 0.0025
# Epoch 51/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5606 - accuracy: 0.0046 - val_loss: 0.4905 - val_accuracy: 0.0025
# Epoch 52/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5574 - accuracy: 0.0043 - val_loss: 0.4269 - val_accuracy: 0.0025
# Epoch 53/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5556 - accuracy: 0.0043 - val_loss: 0.4672 - val_accuracy: 0.0025
# Epoch 54/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5481 - accuracy: 0.0043 - val_loss: 0.4501 - val_accuracy: 0.0025
# Epoch 55/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5448 - accuracy: 0.0043 - val_loss: 0.4229 - val_accuracy: 0.0025
# Epoch 56/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5366 - accuracy: 0.0039 - val_loss: 0.4352 - val_accuracy: 0.0025
# Epoch 57/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5374 - accuracy: 0.0046 - val_loss: 0.4195 - val_accuracy: 0.0025
# Epoch 58/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5567 - accuracy: 0.0043 - val_loss: 0.4318 - val_accuracy: 0.0025
# Epoch 59/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5547 - accuracy: 0.0039 - val_loss: 0.4228 - val_accuracy: 0.0025
# Epoch 60/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5547 - accuracy: 0.0039 - val_loss: 0.4521 - val_accuracy: 0.0025
# Epoch 61/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5507 - accuracy: 0.0053 - val_loss: 0.4757 - val_accuracy: 0.0025
# Epoch 62/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5463 - accuracy: 0.0046 - val_loss: 0.4317 - val_accuracy: 0.0025
# Epoch 63/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5395 - accuracy: 0.0046 - val_loss: 0.4339 - val_accuracy: 0.0025
# Epoch 64/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5366 - accuracy: 0.0039 - val_loss: 0.4193 - val_accuracy: 0.0025
# Epoch 65/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5342 - accuracy: 0.0050 - val_loss: 0.4377 - val_accuracy: 0.0025
# Epoch 66/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5431 - accuracy: 0.0039 - val_loss: 0.4317 - val_accuracy: 0.0025
# Epoch 67/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5369 - accuracy: 0.0036 - val_loss: 0.5201 - val_accuracy: 0.0025
# Epoch 68/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5475 - accuracy: 0.0050 - val_loss: 0.4732 - val_accuracy: 0.0025
# Epoch 69/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5429 - accuracy: 0.0039 - val_loss: 0.4534 - val_accuracy: 0.0025
# Epoch 70/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5441 - accuracy: 0.0043 - val_loss: 0.4361 - val_accuracy: 0.0025
# Epoch 71/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5350 - accuracy: 0.0043 - val_loss: 0.4142 - val_accuracy: 0.0025
# Epoch 72/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5326 - accuracy: 0.0046 - val_loss: 0.4464 - val_accuracy: 0.0025
# Epoch 73/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5462 - accuracy: 0.0043 - val_loss: 0.4424 - val_accuracy: 0.0025
# Epoch 74/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5365 - accuracy: 0.0046 - val_loss: 0.4464 - val_accuracy: 0.0025
# Epoch 75/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5306 - accuracy: 0.0043 - val_loss: 0.4235 - val_accuracy: 0.0025
# Epoch 76/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5279 - accuracy: 0.0039 - val_loss: 0.4303 - val_accuracy: 0.0025
# Epoch 77/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5425 - accuracy: 0.0039 - val_loss: 0.4125 - val_accuracy: 0.0025
# Epoch 78/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5388 - accuracy: 0.0039 - val_loss: 0.4419 - val_accuracy: 0.0025
# Epoch 79/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5361 - accuracy: 0.0043 - val_loss: 0.4303 - val_accuracy: 0.0025
# Epoch 80/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5343 - accuracy: 0.0036 - val_loss: 0.4179 - val_accuracy: 0.0025
# Epoch 81/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5367 - accuracy: 0.0043 - val_loss: 0.4552 - val_accuracy: 0.0025
# Epoch 82/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5407 - accuracy: 0.0039 - val_loss: 0.4532 - val_accuracy: 0.0025
# Epoch 83/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5370 - accuracy: 0.0039 - val_loss: 0.4089 - val_accuracy: 0.0025
# Epoch 84/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5328 - accuracy: 0.0036 - val_loss: 0.4420 - val_accuracy: 0.0025
# Epoch 85/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5196 - accuracy: 0.0039 - val_loss: 0.4330 - val_accuracy: 0.0025
# Epoch 86/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5250 - accuracy: 0.0039 - val_loss: 0.4499 - val_accuracy: 0.0025
# Epoch 87/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5261 - accuracy: 0.0046 - val_loss: 0.4441 - val_accuracy: 0.0025
# Epoch 88/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5301 - accuracy: 0.0036 - val_loss: 0.4606 - val_accuracy: 0.0025
# Epoch 89/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5327 - accuracy: 0.0050 - val_loss: 0.4177 - val_accuracy: 0.0025
# Epoch 90/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5366 - accuracy: 0.0043 - val_loss: 0.4396 - val_accuracy: 0.0025
# Epoch 91/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5369 - accuracy: 0.0050 - val_loss: 0.4267 - val_accuracy: 0.0025
# Epoch 92/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5230 - accuracy: 0.0043 - val_loss: 0.4802 - val_accuracy: 0.0025
# Epoch 93/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5355 - accuracy: 0.0036 - val_loss: 0.4172 - val_accuracy: 0.0025
# Epoch 94/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5296 - accuracy: 0.0039 - val_loss: 0.4558 - val_accuracy: 0.0025
# Epoch 95/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5349 - accuracy: 0.0043 - val_loss: 0.4935 - val_accuracy: 0.0025
# Epoch 96/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5296 - accuracy: 0.0046 - val_loss: 0.4485 - val_accuracy: 0.0025
# Epoch 97/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5259 - accuracy: 0.0046 - val_loss: 0.4305 - val_accuracy: 0.0025
# Epoch 98/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5252 - accuracy: 0.0046 - val_loss: 0.4364 - val_accuracy: 0.0025
# Epoch 99/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5226 - accuracy: 0.0046 - val_loss: 0.4391 - val_accuracy: 0.0025
# Epoch 100/100
# 88/88 [==============================] - 1s 12ms/step - loss: 0.5385 - accuracy: 0.0043 - val_loss: 0.4345 - val_accuracy: 0.0025

# %%
y_pred = model.predict(X_test)
# Out:
# 38/38 [==============================] - 0s 4ms/step

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
history = model_fit.history

# %%
history = pd.DataFrame(history)

# %%
plot_tf_hist(history)
