# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %% [markdown]
# ### Global_variables

# %%
RANDOM_STATE = 42

# %%
features, labels = datasets.make_moons(n_samples = 1000, noise = 0.2, random_state = RANDOM_STATE)

# %%
features.shape
# Out:
# (1000, 2)

# %%
labels.shape
# Out:
# (1000,)

# %%
data_df = pd.DataFrame(features, columns=['X1', 'X2'])

# %%
data_df['target'] = labels

# %%
data_df
# Out:
#            X1        X2  target
# 0   -0.111667  0.520224       1
# 1    1.142650 -0.342577       1
# 2    0.795558 -0.011442       1
# 3    0.111827 -0.551932       1
# 4   -0.816466  0.543996       0
# ..        ...       ...     ...
# 995  0.835830  0.435532       0
# 996 -0.195852  0.833794       0
# 997  1.727608 -0.428829       1
# 998 -1.014486  0.135229       0
# 999  0.774381  0.634285       0
#
# [1000 rows x 3 columns]

# %%
data_df.plot(kind = 'scatter', x = 'X1', y = 'X2', cmap = 'autumn')
plt.show()
# Out:
# /home/dai/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1266: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
sns.scatterplot(data=data_df, x='X1', y='X2', hue='target', s=data_df['X1']*10)
plt.show()
# Out:
# /home/dai/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/dai/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/dai/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
